# %% [markdown]
# <a href="https://colab.research.google.com/github/AmitBytesSage/Convolutional-Neural-Networks/blob/main/Neural_Nets_Project_Starter_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
import numpy as np
import os
import datetime
import abc
import cv2
import matplotlib.pyplot as plt
import pathlib
import time
from sys import getsizeof
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
from tensorflow import random
random.set_seed(30)

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip "/content/gdrive/MyDrive/GestureDetection/Project_data.Zip" -d "/content"

# %%
project_folder='/content/gdrive/MyDrive/GestureDetection/content/Project_data'

# %% [markdown]
# ### Plotting

# %%
# function to plot the training/validation accuracies/losses.

def plot(history):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))
    axes[0].plot(history.history['loss'])
    axes[0].plot(history.history['val_loss'])
    axes[0].legend(['loss','val_loss'])

    axes[1].plot(history.history['categorical_accuracy'])
    axes[1].plot(history.history['val_categorical_accuracy'])
    axes[1].legend(['categorical_accuracy','val_categorical_accuracy'])

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
# train_doc = np.random.permutation(open(pathlib.Path(project_folder+'/train.csv')).readlines())
# val_doc = np.random.permutation(open(pathlib.Path(project_folder+'/val.csv')).readlines())
# batch_size = 10 #experiment with the batch size

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
class ModelBuilder(metaclass= abc.ABCMeta):
    # initialisng the path where project data resides
    def initialize_path(self, project_folder):
        self.train_doc = np.random.permutation(open(pathlib.Path(project_folder + '/' + 'train.csv')).readlines())
        self.val_doc = np.random.permutation(open(pathlib.Path(project_folder + '/' + 'val.csv')).readlines())
        self.train_path = project_folder + '/' + 'train'
        self.val_path =  project_folder + '/' + 'val'
        self.num_train_sequences = len(self.train_doc)
        self.num_val_sequences = len(self.val_doc)

    # initialising the image properties
    def initialize_image_properties(self,image_height=100,image_width=100):
        self.image_height=image_height
        self.image_width=image_width
        self.channels=3
        self.num_classes=5
        self.total_frames=30

    # initialising the batch size, frames to sample and the no. of epochs
    def initialize_hyperparams(self,frames_to_sample=30,batch_size=20,num_epochs=20):
        self.frames_to_sample=frames_to_sample
        self.batch_size=batch_size
        self.num_epochs=num_epochs

    def train_model(self, model, augment_data=False):
        print("train model")
        train_generator = self.generator(self.train_path, self.train_doc,augment=augment_data)
        val_generator = self.generator(self.val_path, self.val_doc)

        model_name = 'model_init' + '_' + str(datetime.datetime.now()).replace(' ','').replace(':','_') + '/'

        if not os.path.exists(model_name):
            os.mkdir(model_name)

        filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

        checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto')
        LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)

        earlystop = EarlyStopping( monitor="val_loss", min_delta=0,patience=10,verbose=1)
        callbacks_list = [checkpoint, LR, earlystop]

        if (self.num_train_sequences%self.batch_size) == 0:
            steps_per_epoch = int(self.num_train_sequences/self.batch_size)
        else:
            steps_per_epoch = (self.num_train_sequences//self.batch_size) + 1

        if (self.num_val_sequences%self.batch_size) == 0:
            validation_steps = int(self.num_val_sequences/self.batch_size)
        else:
            validation_steps = (self.num_val_sequences//self.batch_size) + 1

        history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=self.num_epochs, verbose=1,
                            callbacks=callbacks_list, validation_data=val_generator,
                            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
        return history

    def generator(self, source_path, folder_list, augment=False):
      print( 'Source path = ', source_path, '; batch size =', self.batch_size)
      img_idx = np.round(np.linspace(0,self.total_frames-1,self.frames_to_sample)).astype(int)
      batch_size=self.batch_size
      while True:
          t = np.random.permutation(folder_list)
          num_batches =len(t)
          for batch in range(num_batches):
              batch_data =  np.zeros((batch_size, len(img_idx),self.image_height,self.image_width,self.channels))
              batch_labels = np.zeros((batch_size,5))
              for folder in range(batch_size): # iterate over the batch_size
                  imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                  for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                      image = cv2.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                      #crop the images and resize them. Note that the images are of 2 different shape
                      #and the conv3D will throw error if the inputs in a batch have different shapes
                      image_resized= cv2.resize(image, (self.image_height, self.image_width), interpolation = cv2.INTER_NEAREST)

                      batch_data[folder, idx, :, :, 0] = (image_resized[:,:,0])/255
                      batch_data[folder, idx, :, :, 1] = (image_resized[:,:,1])/255
                      batch_data[folder, idx, :, :, 2] = (image_resized[:,:,2])/255


                  batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
              yield batch_data, batch_labels

    # def generatorOld(self,source_path, folder_list, augment=False):
    #     print("generator")
    #     start = time.time()
    #     img_idx = np.round(np.linspace(0,self.total_frames-1,self.frames_to_sample)).astype(int)
    #     batch_size=self.batch_size
    #     while True:
    #         t = np.random.permutation(folder_list)
    #         num_batches = len(t)//batch_size

    #         for batch in range(num_batches):
    #             startBatch = time.time()
    #             batch_data, batch_labels= self.one_batch_data(source_path, t, batch, batch_size, img_idx, augment)
    #             yield batch_data, batch_labels
    #             end = time.time()
    #             print(f"Time taken: {(end-startBatch):.03f}s")

    #         remaining_seq=len(t)%batch_size

    #         if (remaining_seq != 0):
    #             print("Remaining bach")
    #             batch_data, batch_labels= self.one_batch_data(source_path,t,num_batches,batch_size,img_idx,augment,remaining_seq)
    #             yield batch_data, batch_labels
    #     end = time.time()
    #     print(f"Genertor Time taken: {(end-start):.03f}s")

    # def one_batch_data(self, source_path, t, batch, batch_size, img_idx, augment, remaining_seq=0):
    #     print("get batch data")
    #     start = time.time()
    #     seq_len = remaining_seq if remaining_seq else batch_size

    #     batch_data = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels))
    #     batch_labels = np.zeros((seq_len,self.num_classes))

    #     if (augment): batch_data_aug = np.zeros((seq_len,len(img_idx),self.image_height, self.image_width,self.channels))

    #     print("start reading and resizing")
    #     for folder in range(seq_len):
    #         imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0])
    #         for idx,item in enumerate(img_idx):
    #             #performing image reading and resizing
    #             image = cv2.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

    #             image_resized= cv2.resize(image, (self.image_height, self.image_width), interpolation = cv2.INTER_NEAREST)

    #             #normalizing the images
    #             batch_data[folder, idx, :, :, 0] = (image_resized[:,:,0])/255
    #             batch_data[folder, idx, :, :, 1] = (image_resized[:,:,1])/255
    #             batch_data[folder, idx, :, :, 2] = (image_resized[:,:,2])/255

    #             if (augment):
    #                 # print("Perform augmentation")
    #                 shifted = cv2.warpAffine(image,
    #                                          np.float32([[1, 0, np.random.randint(-30,30)],[0, 1, np.random.randint(-30,30)]]),
    #                                         (image.shape[1], image.shape[0]))

    #                 gray = cv2.cvtColor(shifted, cv2.COLOR_BGR2GRAY)

    #                 x0, y0 = np.argwhere(gray > 0).min(axis=0)
    #                 x1, y1 = np.argwhere(gray > 0).max(axis=0)
    #                 # cropping the images to have the targeted gestures and remove the noise from the images.

    #                 cropped=shifted[x0:x1,y0:y1,:]

    #                 image_resized = cv2.resize(cropped, (self.image_height, self.image_width), interpolation = cv2.INTER_NEAREST)

    #                 #shifted = cv2.warpAffine(image_resized,
    #                 #                        np.float32([[1, 0, np.random.randint(-3,3)],[0, 1, np.random.randint(-3,3)]]),
    #                 #                        (image_resized.shape[1], image_resized.shape[0]))

    #                 batch_data_aug[folder, idx, :, :, 0] = (image_resized[:,:,0])/255
    #                 batch_data_aug[folder, idx, :, :, 1] = (image_resized[:,:,1])/255
    #                 batch_data_aug[folder, idx, :, :, 2] = (image_resized[:,:,2])/255


    #         batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1


    #     if (augment):
    #         batch_data=np.concatenate([batch_data, batch_data_aug])
    #         batch_labels=np.concatenate([batch_labels, batch_labels])
    #     return(batch_data,batch_labels)




    @abc.abstractmethod
    def define_model(self):
        pass

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
# curr_dt_time = datetime.datetime.now()
# train_path = '/notebooks/storage/Final_data/Collated_training/train'
# val_path = '/notebooks/storage/Final_data/Collated_training/val'
# num_train_sequences = len(train_doc)
# print('# training sequences =', num_train_sequences)
# num_val_sequences = len(val_doc)
# print('# validation sequences =', num_val_sequences)
# num_epochs = 10# choose the number of epochs
# print ('# epochs =', num_epochs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-36037b731ad6> in <cell line: 4>()
#       2 train_path = '/notebooks/storage/Final_data/Collated_training/train'
#       3 val_path = '/notebooks/storage/Final_data/Collated_training/val'
# ----> 4 num_train_sequences = len(train_doc)
#       5 print('# training sequences =', num_train_sequences)
#       6 num_val_sequences = len(val_doc)
#
# NameError: name 'train_doc' is not defined

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation
from keras.layers import Conv2D, Conv3D, MaxPooling3D, MaxPooling2D, LSTM
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras import optimizers
from keras.layers import Dropout

# %% [markdown]
# ### Sample Model

# %%
class ModelConv3D(ModelBuilder):

    def define_model(self):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        # model.add(Conv3D(64, (2, 2, 2), padding='same'))
        # model.add(Activation('relu'))
        # model.add(BatchNormalization())
        # model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        # model.add(Flatten())
        # model.add(Dense(128,activation='relu'))
        # model.add(BatchNormalization())
        # model.add(Dropout(0.5))

        model.add(Flatten())
        model.add(Dense(64,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.25))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam()

        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d1 = ModelConv3D()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=30,batch_size=10,num_epochs=1)
conv_3d1_model=conv_3d1.define_model()
conv_3d1_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 30, 160, 160, 16   1312
#                              )
#
#  activation (Activation)     (None, 30, 160, 160, 16   0
#                              )
#
#  batch_normalization (Batch  (None, 30, 160, 160, 16   64
#  Normalization)              )
#
#  max_pooling3d (MaxPooling3  (None, 15, 80, 80, 16)    0
#  D)
#
#  conv3d_1 (Conv3D)           (None, 15, 80, 80, 32)    4128
#
#  activation_1 (Activation)   (None, 15, 80, 80, 32)    0
#
#  batch_normalization_1 (Bat  (None, 15, 80, 80, 32)    128
#  chNormalization)
#
#  max_pooling3d_1 (MaxPoolin  (None, 7, 40, 40, 32)     0
#  g3D)
#
#  flatten (Flatten)           (None, 358400)            0
#
#  dense (Dense)               (None, 64)                22937664
#
#  batch_normalization_2 (Bat  (None, 64)                256
#  chNormalization)
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 22943877 (87.52 MB)
# Trainable params: 22943653 (87.52 MB)
# Non-trainable params: 224 (896.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Sample Cropping

# %%
test_generator = ModelConv3D()
test_generator.initialize_path(project_folder)
test_generator.initialize_image_properties(image_height=160,image_width=160)
test_generator.initialize_hyperparams(frames_to_sample=30,batch_size=3,num_epochs=1)

# %%
g = test_generator.generator(test_generator.val_path, test_generator.val_doc, augment=True)
batch_data, batch_labels=next(g)
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].imshow(batch_data[0,15,:,:,:])
axes[1].imshow(batch_data[3,15,:,:,:])
# Out:
# Source path =  /content/gdrive/MyDrive/GestureDetection/storage/val ; batch size = 3
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-e1e4980b72cb> in <cell line: 5>()
#       3 fig, axes = plt.subplots(nrows=1, ncols=2)
#       4 axes[0].imshow(batch_data[0,15,:,:,:])
# ----> 5 axes[1].imshow(batch_data[3,15,:,:,:])
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %% [markdown]
# ### Experimenting with Image resolution, number of frames to use and batch_size

# %%
#conv_3d1.train_model(conv_3d1_model)
# Out:
#  3/67 [>.............................] - ETA: 1:05:38 - loss: 1.8607 - categorical_accuracy: 0.3667

# %% [markdown]
# ### It is taking too much time to process

# %%
print("Memory util is {} Gigs". format(getsizeof(np.zeros((40,16,30,160,160)))/(1024*1024*1024)))
# Out:
# Memory util is 3.662109538912773 Gigs

# %% [markdown]
# #### So lets trade-off between these parameters

# %% [markdown]
# #### Below are the experiments to see how training time is affected by image resolution, number of images in sequence and batch size

# %%
conv_3d1 = ModelConv3D()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=100,image_width=100)
conv_3d1.initialize_hyperparams(frames_to_sample=15,batch_size=30,num_epochs=2)

conv_3d1_model= conv_3d1.define_model()
print("Total Params:", conv_3d1_model.count_params())
conv_3d1.train_model(conv_3d1_model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-b4ba204bb725> in <cell line: 6>()
#       4 conv_3d1.initialize_hyperparams(frames_to_sample=15,batch_size=30,num_epochs=2)
#       5
# ----> 6 conv_3d1_model= conv_3d1.define_model()
#       7 print("Total Params:", conv_3d1_model.count_params())
#       8 conv_3d1.train_model(conv_3d1_model)
#
# <ipython-input-11-a110d0244adb> in define_model(self)
#      23         model.add(Activation('relu'))
#      24         model.add(BatchNormalization())
# ---> 25         model.add(MaxPooling3D(pool_size=(2, 2, 2)))
#      26
#      27         model.add(Flatten())
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/trackable/base.py in _method_wrapper(self, *args, **kwargs)
#     202     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     203     try:
# --> 204       result = method(self, *args, **kwargs)
#     205     finally:
#     206       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1018   except errors.InvalidArgumentError as e:
#    1019     # Convert to ValueError for backwards compatibility.
# -> 1020     raise ValueError(e.message)
#    1021
#    1022   # Record the current Python stack trace as the creating stacktrace of this
#
# ValueError: Exception encountered when calling layer "max_pooling3d_7" (type MaxPooling3D).
#
# Negative dimension size caused by subtracting 2 from 1 for '{{node max_pooling3d_7/MaxPool3D}} = MaxPool3D[T=DT_FLOAT, data_format="NDHWC", ksize=[1, 2, 2, 2, 1], padding="VALID", strides=[1, 2, 2, 2, 1]](Placeholder)' with input shapes: [?,1,12,12,128].
#
# Call arguments received by layer "max_pooling3d_7" (type MaxPooling3D):
#   • inputs=tf.Tensor(shape=(None, 1, 12, 12, 128), dtype=float32)

# %%
conv_3d1 = ModelConv3D()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=100,image_width=100)
conv_3d1.initialize_hyperparams(frames_to_sample=30,batch_size=20,num_epochs=2)
conv_3d1_model=conv_3d1.define_model()
print("Total Params:", conv_3d1_model.count_params())
conv_3d1.train_model(conv_3d1_model)
# Out:
# Total Params: 8966277
# train model
# Source path =  /content/gdrive/MyDrive/GestureDetection/storage/train ; batch size = 20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-fbb175d69b54> in <cell line: 7>()
#       5 conv_3d1_model=conv_3d1.define_model()
#       6 print("Total Params:", conv_3d1_model.count_params())
# ----> 7 conv_3d1.train_model(conv_3d1_model)
#
# <ipython-input-6-b2709695b81d> in train_model(self, model, augment_data)
#      51             validation_steps = (self.num_val_sequences//self.batch_size) + 1
#      52
# ---> 53         history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=self.num_epochs, verbose=1,
#      54                             callbacks=callbacks_list, validation_data=val_generator,
#      55                             validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2911             stacklevel=2,
#    2912         )
# -> 2913         return self.fit(
#    2914             generator,
#    2915             steps_per_epoch=steps_per_epoch,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1743         ):
#    1744             # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1745             data_handler = data_adapter.get_data_handler(
#    1746                 x=x,
#    1747                 y=y,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in get_data_handler(*args, **kwargs)
#    1686             return _ClusterCoordinatorExactEvalDataHandler(*args, **kwargs)
#    1687         return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1688     return DataHandler(*args, **kwargs)
#    1689
#    1690
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute, pss_evaluation_shards)
#    1290
#    1291         adapter_cls = select_data_adapter(x, y)
# -> 1292         self._adapter = adapter_cls(
#    1293             x,
#    1294             y,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in __init__(self, x, y, sample_weights, workers, use_multiprocessing, max_queue_size, model, **kwargs)
#     881         # Since we have to know the dtype of the python generator when we build
#     882         # the dataset, we have to look at a batch to infer the structure.
# --> 883         peek, x = self._peek_and_restore(x)
#     884         peek = self._standardize_batch(peek)
#     885         peek = _process_tensorlike(peek)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in _peek_and_restore(x)
#     947     @staticmethod
#     948     def _peek_and_restore(x):
# --> 949         peek = next(x)
#     950         return peek, itertools.chain([peek], x)
#     951
#
# <ipython-input-6-b2709695b81d> in generator(self, source_path, folder_list, augment)
#      69                   imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
#      70                   for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
# ---> 71                       image = cv2.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
#      72
#      73                       #crop the images and resize them. Note that the images are of 2 different shape
#
# KeyboardInterrupt:

# %%
conv_3d1=ModelConv3D()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=30,batch_size=15,num_epochs=2)
conv_3d1_model=conv_3d1.define_model()
print("Total Params:", conv_3d1_model.count_params())
conv_3d1.train_model(conv_3d1_model)

# %%
conv_3d1=ModelConv3D()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=16,batch_size=30,num_epochs=2)
conv_3d1_model=conv_3d1.define_model()
print("Total Params:", conv_3d1_model.count_params())
conv_3d1.train_model(conv_3d1_model)

# %% [markdown]
# * As we see from the above experiments "image resolution" and number of frames in sequence have more impact on training time than batch_size
# * We can consider the Batch Size around 15-40
# * We will change the resoulution 160x160, 120x120 according the model performance

# %% [markdown]
# ### Model 1

# %% [markdown]
# ### Base Model - Batch Size = 40 and No. of Epochs = 15

# %%
class ModelConv3D1(ModelBuilder):

    def define_model(self, filtersize = (3,3,3), dense_neurons=64, dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d1 = ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=20,batch_size=40,num_epochs=15)
conv_3d1_model=conv_3d1.define_model()
conv_3d1_model.summary()

# %%
print("Total Params:", conv_3d1_model.count_params())
history_model1 = conv_3d1.train_model(conv_3d1_model)

# %%
plot(history_model1)

# %% [markdown]
# #### Model is clearly overfitting. :(

# %% [markdown]
# ### Model 2

# %% [markdown]
# ##### Adding dropout layers - Batch Size = 20 and No. of Epochs = 25

# %%
conv_3d2 = ModelConv3D1()
conv_3d2.initialize_path(project_folder)
conv_3d2.initialize_image_properties(image_height=160,image_width=160)
conv_3d2.initialize_hyperparams(frames_to_sample=20,batch_size=20,num_epochs=25)
conv_3d2_model= conv_3d2.define_model(dense_neurons = 256, dropout=0.5)
conv_3d2_model.summary()

# %%
print("Total Params:", conv_3d2_model.count_params())
history_model2=conv_3d2.train_model(conv_3d2_model,augment_data=True)

# %%
plot(history_model2)

# %% [markdown]
# ### We can see val_loss did not improve from 1.24219 so earlystopping stops the epoch automatically!!
# * Last Epoch stop on 15/25!! good job earlystopping ;)
# * Best weights save automatically. The validation accuracy of 52% and training accuracy of 65%. Next we will try to reduce the filter size and image resolution and see if get better results. Moreover since we see minor oscillations in loss, let's try lowering the learning rate to 0.0002

# %% [markdown]
# ### Model 3

# %% [markdown]
# ##### Reduce filter size to (2,2,2) and image res to 120 x 120, - Batch Size = 30 and No. of Epochs = 25

# %%
class ModelConv3D3(ModelBuilder):

    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam(learning_rate=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d3=ModelConv3D3()
conv_3d3.initialize_path(project_folder)
conv_3d3.initialize_image_properties(image_height=120,image_width=120)
conv_3d3.initialize_hyperparams(frames_to_sample=16,batch_size=30,num_epochs=25)
conv_3d3_model=conv_3d3.define_model(filtersize=(2,2,2),dense_neurons=256,dropout=0.5)
conv_3d3_model.summary()

# %%
print("Total Params:", conv_3d3_model.count_params())
history_model3=conv_3d3.train_model(conv_3d3_model,augment_data=True)

# %%
plot(history_model3)

# %% [markdown]
# ##### Model has a best validation accuracy of 72% and training accuracy of 76% . Also we were able to reduce the parameter size by half the earlier model. Let's trying adding more layers

# %% [markdown]
# ### Model 4 -

# %% [markdown]
# ##### Adding more layers - Batch Size = 20 and No. of Epochs = 25

# %%
class ModelConv3D4(ModelBuilder):

    def define_model(self,filtersize=(3,3,3), dense_neurons=64, dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling3D(pool_size=(2, 2, 2)))


        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d4 = ModelConv3D4()
conv_3d4.initialize_path(project_folder)
conv_3d4.initialize_image_properties(image_height=120,image_width=120)
conv_3d4.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=25)
conv_3d4_model=conv_3d4.define_model(filtersize=(3,3,3),dense_neurons=256,dropout=0.5)
conv_3d4_model.summary()

# %%
print("Total Params:", conv_3d4_model.count_params())
history_model4=conv_3d4.train_model(conv_3d4_model,augment_data=True)

# %%
plot(history_model4)

# %% [markdown]
# #### With more layers we dont see much performance improvement. We get a best validation accuracy of 76% . Let's try adding dropouts at the convolution layers

# %% [markdown]
# ### Model 5
# #### Adding dropout at convolution layers

# %%
class ModelConv3D5(ModelBuilder):

    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model.add(Dropout(dropout))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model.add(Dropout(dropout))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model.add(Dropout(dropout))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model.add(Dropout(dropout))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d5=ModelConv3D5()
conv_3d5.initialize_path(project_folder)
conv_3d5.initialize_image_properties(image_height=120,image_width=120)
conv_3d5.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=15)
conv_3d5_model=conv_3d5.define_model(filtersize=(3,3,3),dense_neurons=256,dropout=0.25)
conv_3d5_model.summary()

# %%
print("Total Params:", conv_3d5_model.count_params())
history_model5=conv_3d5.train_model(conv_3d5_model,augment_data=True)

# %%
plot(history_model5)

# %% [markdown]
# #### Ohh! Overfitting again!! Adding dropouts has further reduced validation accuracy as the model doesn't seem to generalise well.

# %% [markdown]
# **All the experimental models above have more than 1 million parameters. Let's try to reduce the model size and see the performance**

# %% [markdown]
# ## Model 6
# ### Reducing the number of parameters

# %%
class ModelConv3D6(ModelBuilder):

    def define_model(self,dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam(learning_rate=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d6=ModelConv3D6()
conv_3d6.initialize_path(project_folder)
conv_3d6.initialize_image_properties(image_height=100,image_width=100)
conv_3d6.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=20)
conv_3d6_model=conv_3d6.define_model(dense_neurons=128,dropout=0.25)
conv_3d6_model.summary()

# %%
print("Total Params:", conv_3d6_model.count_params())
history_model6=conv_3d6.train_model(conv_3d6_model,augment_data=True)

# %%
plot(history_model6)

# %% [markdown]
# For the above low memory foot print model, we get the best validation accuracy of 74%

# %% [markdown]
# ## Model 7 - Reducing the number of parameters again

# %%
class ModelConv3D7(ModelBuilder):

    def define_model(self,dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (3, 3, 3), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam(learning_rate=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d7=ModelConv3D7()
conv_3d7.initialize_path(project_folder)
conv_3d7.initialize_image_properties(image_height=120,image_width=120)
conv_3d7.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=25)
conv_3d7_model=conv_3d7.define_model(dense_neurons=64,dropout=0.25)
conv_3d7_model.summary()

# %%
print("Total Params:", conv_3d7_model.count_params())
history_model7=conv_3d7.train_model(conv_3d7_model,augment_data=True)

# %%
plot(history_model7)

# %% [markdown]
# For the above low memory foot print model the best validation accuracy of 73%

# %% [markdown]
# ## Model 8 - CNN- LSTM Model

# %%
class RNNCNN1(ModelBuilder):

    def define_model(self,lstm_cells=64,dense_neurons=64,dropout=0.25):

        model = Sequential()

        model.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu'),
                                  input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))

        model.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))

        model.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))

        model.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))

        model.add(TimeDistributed(Conv2D(256, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))

        #model.add(TimeDistributed(Conv2D(512, (2, 2) , padding='valid', activation='relu')))
       # model.add(TimeDistributed(BatchNormalization()))
       # model.add(TimeDistributed(MaxPooling2D((2, 2))))

        model.add(TimeDistributed(Flatten()))


        model.add(LSTM(lstm_cells))
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(Dropout(dropout))

        model.add(Dense(self.num_classes, activation='softmax'))
        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
rnn_cnn1=RNNCNN1()
rnn_cnn1.initialize_path(project_folder)
rnn_cnn1.initialize_image_properties(image_height=120,image_width=120)
rnn_cnn1.initialize_hyperparams(frames_to_sample=18,batch_size=20,num_epochs=20)
rnn_cnn1_model=rnn_cnn1.define_model(lstm_cells=128,dense_neurons=128,dropout=0.25)
rnn_cnn1_model.summary()

# %%
print("Total Params:", rnn_cnn1_model.count_params())
history_model8=rnn_cnn1.train_model(rnn_cnn1_model,augment_data=True)

# %%
plot(history_model8)

# %% [markdown]
# ### For CNN - LSTM model we get a best validation accuracy of 85%
# As we see more cases of overfitting, lets augment the data with ***slight rotation*** as well and run the same set of models again

# %% [markdown]
# ## Let's apply some data augmentation & check the model performance.

# %%
class ModelBuilderMoreAugmentation(metaclass= abc.ABCMeta):

    def initialize_path(self,project_folder):
        self.train_doc = np.random.permutation(open(project_folder + '/' + 'train.csv').readlines())
        self.val_doc = np.random.permutation(open(project_folder + '/' + 'val.csv').readlines())
        self.train_path = project_folder + '/' + 'train'
        self.val_path =  project_folder + '/' + 'val'
        self.num_train_sequences = len(self.train_doc)
        self.num_val_sequences = len(self.val_doc)

    def initialize_image_properties(self,image_height=100,image_width=100):
        self.image_height=image_height
        self.image_width=image_width
        self.channels=3
        self.num_classes=5
        self.total_frames=30

    def initialize_hyperparams(self,frames_to_sample=30,batch_size=20,num_epochs=20):
        self.frames_to_sample=frames_to_sample
        self.batch_size=batch_size
        self.num_epochs=num_epochs


    def generator(self,source_path, folder_list, augment=False):
        img_idx = np.round(np.linspace(0,self.total_frames-1,self.frames_to_sample)).astype(int)
        batch_size=self.batch_size
        while True:
            t = np.random.permutation(folder_list)
            num_batches = len(t)//batch_size

            for batch in range(num_batches):
                batch_data, batch_labels= self.one_batch_data(source_path,t,batch,batch_size,img_idx,augment)
                yield batch_data, batch_labels

            remaining_seq=len(t)%batch_size

            if (remaining_seq != 0):
                batch_data, batch_labels= self.one_batch_data(source_path,t,num_batches,batch_size,img_idx,augment,remaining_seq)
                yield batch_data, batch_labels


    def one_batch_data(self,source_path,t,batch,batch_size,img_idx,augment,remaining_seq=0):

        seq_len = remaining_seq if remaining_seq else batch_size

        batch_data = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels))
        batch_labels = np.zeros((seq_len,self.num_classes))

        if (augment): batch_data_aug = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels))


        for folder in range(seq_len):
            imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0])
            for idx,item in enumerate(img_idx):
                image = cv2.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                image_resized= cv2.resize(image,(self.image_height,self.image_width), interpolation = cv2.INTER_LINEAR)


                batch_data[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                batch_data[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                batch_data[folder,idx,:,:,2] = (image_resized[:,:,2])/255

                if (augment):
                    shifted = cv2.warpAffine(image,
                                             np.float32([[1, 0, np.random.randint(-30,30)],[0, 1, np.random.randint(-30,30)]]),
                                            (image.shape[1], image.shape[0]))

                    gray = cv2.cvtColor(shifted,cv2.COLOR_BGR2GRAY)

                    x0, y0 = np.argwhere(gray > 0).min(axis=0)
                    x1, y1 = np.argwhere(gray > 0).max(axis=0)

                    cropped=shifted[x0:x1,y0:y1,:]

                    image_resized= cv2.resize(cropped,(self.image_height,self.image_width), interpolation = cv2.INTER_LINEAR)

                    M = cv2.getRotationMatrix2D((self.image_width//2,self.image_height//2),
                                                np.random.randint(-10,10), 1.0)
                    rotated = cv2.warpAffine(image_resized, M, (self.image_width, self.image_height))

                    #shifted = cv2.warpAffine(image_resized,
                    #                        np.float32([[1, 0, np.random.randint(-3,3)],[0, 1, np.random.randint(-3,3)]]),
                    #                        (image_resized.shape[1], image_resized.shape[0]))

                    batch_data_aug[folder,idx,:,:,0] = (rotated[:,:,0])/255
                    batch_data_aug[folder,idx,:,:,1] = (rotated[:,:,1])/255
                    batch_data_aug[folder,idx,:,:,2] = (rotated[:,:,2])/255


            batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1


        if (augment):
            batch_data=np.concatenate([batch_data,batch_data_aug])
            batch_labels=np.concatenate([batch_labels,batch_labels])


        return(batch_data,batch_labels)


    def train_model(self, model, augment_data=False):
        train_generator = self.generator(self.train_path, self.train_doc,augment=augment_data)
        val_generator = self.generator(self.val_path, self.val_doc)

        model_name = 'model_init' + '_' + str(datetime.datetime.now()).replace(' ','').replace(':','_') + '/'

        if not os.path.exists(model_name):
            os.mkdir(model_name)

        filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

        checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto')
        LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)
        callbacks_list = [checkpoint, LR]

        if (self.num_train_sequences%self.batch_size) == 0:
            steps_per_epoch = int(self.num_train_sequences/self.batch_size)
        else:
            steps_per_epoch = (self.num_train_sequences//self.batch_size) + 1

        if (self.num_val_sequences%self.batch_size) == 0:
            validation_steps = int(self.num_val_sequences/self.batch_size)
        else:
            validation_steps = (self.num_val_sequences//self.batch_size) + 1

        history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=self.num_epochs, verbose=1,
                            callbacks=callbacks_list, validation_data=val_generator,
                            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
        return history


    @abc.abstractmethod
    def define_model(self):
        pass

# %%
class Test(ModelBuilderMoreAugmentation):
    def define_model(self):
        pass

test_generator=Test()
test_generator.initialize_path(project_folder)
test_generator.initialize_image_properties(image_height=160,image_width=160)
test_generator.initialize_hyperparams(frames_to_sample=30,batch_size=3,num_epochs=1)

g=test_generator.generator(test_generator.val_path,test_generator.val_doc,augment=True)
batch_data, batch_labels=next(g)
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].imshow(batch_data[0,29,:,:,:])
axes[1].imshow(batch_data[3,29,:,:,:])

# %% [markdown]
# ## Model 9 with Augmentation
# ### (3,3,3) Filter & 160x160 Image resolution - similar to Model 2

# %%
class ModelConv3D9(ModelBuilderMoreAugmentation):

    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam(learning_rate=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d9=ModelConv3D9()
conv_3d9.initialize_path(project_folder)
conv_3d9.initialize_image_properties(image_height=160,image_width=160)
conv_3d9.initialize_hyperparams(frames_to_sample=20,batch_size=20,num_epochs=20)
conv_3d9_model=conv_3d9.define_model(dense_neurons=256,dropout=0.5)
conv_3d9_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 20, 160, 160, 16   1312
#                              )
#
#  activation (Activation)     (None, 20, 160, 160, 16   0
#                              )
#
#  batch_normalization (Batch  (None, 20, 160, 160, 16   64
#  Normalization)              )
#
#  max_pooling3d (MaxPooling3  (None, 10, 80, 80, 16)    0
#  D)
#
#  conv3d_1 (Conv3D)           (None, 10, 80, 80, 32)    13856
#
#  activation_1 (Activation)   (None, 10, 80, 80, 32)    0
#
#  batch_normalization_1 (Bat  (None, 10, 80, 80, 32)    128
# 2024-03-03 15:20:57.128617: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-03 15:20:57.477308: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-03 15:20:57.477352: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-03 15:20:57.479887: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-03 15:20:57.479931: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-03 15:20:57.479951: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-03 15:20:57.623472: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-03 15:20:57.623547: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-03 15:20:57.623557: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-03-03 15:20:57.623588: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-03 15:20:57.623605: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2248 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
#  chNormalization)
#
#  max_pooling3d_1 (MaxPoolin  (None, 5, 40, 40, 32)     0
#  g3D)
#
#  conv3d_2 (Conv3D)           (None, 5, 40, 40, 64)     55360
#
#  activation_2 (Activation)   (None, 5, 40, 40, 64)     0
#
#  batch_normalization_2 (Bat  (None, 5, 40, 40, 64)     256
#  chNormalization)
#
#  max_pooling3d_2 (MaxPoolin  (None, 2, 20, 20, 64)     0
#  g3D)
#
#  conv3d_3 (Conv3D)           (None, 2, 20, 20, 128)    221312
#
#  activation_3 (Activation)   (None, 2, 20, 20, 128)    0
#
#  batch_normalization_3 (Bat  (None, 2, 20, 20, 128)    512
#  chNormalization)
#
#  max_pooling3d_3 (MaxPoolin  (None, 1, 10, 10, 128)    0
#  g3D)
#
#  flatten (Flatten)           (None, 12800)             0
#
#  dense (Dense)               (None, 256)               3277056
#
#  batch_normalization_4 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  batch_normalization_5 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 3638981 (13.88 MB)
# Trainable params: 3637477 (13.88 MB)
# Non-trainable params: 1504 (5.88 KB)
# _________________________________________________________________

# %%
print("Total Params:", conv_3d9_model.count_params())
history_model9=conv_3d9.train_model(conv_3d9_model,augment_data=True)
# Out:
# Total Params: 3638981
# Epoch 1/20
# 2024-03-03 15:21:06.064643: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.24GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-03 15:21:06.064700: W tensorflow/core/kernels/gpu_utils.cc:54] Failed to allocate memory for convolution redzone checking; skipping this check. This is benign and only means that we won't check cudnn for out-of-bounds reads and writes. This message will only be printed once.
# 2024-03-03 15:21:06.122952: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-03-03 15:21:06.694908: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-03-03 15:21:06.697529: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: Not a directory
# 2024-03-03 15:21:06.747336: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-03-03 15:21:06.747416: W external/local_xla/xla/stream_executor/gpu/asm_compiler.cc:110] Couldn't get ptxas version : FAILED_PRECONDITION: Couldn't get ptxas/nvlink version string: INTERNAL: Couldn't invoke ptxas --version
# 2024-03-03 15:21:06.796748: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-03-03 15:21:06.796869: W external/local_xla/xla/stream_executor/gpu/redzone_allocator.cc:322] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2024-03-03 15:21:11.491536: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-03-03 15:21:21.642611: W external/local_tsl/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.22GiB (rounded to 1310720000)requested by op sequential/batch_normalization/FusedBatchNormV3
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2024-03-03 15:21:21.642660: I external/local_tsl/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2024-03-03 15:21:21.642671: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 74, Chunks in use: 73. 18.5KiB allocated for chunks. 18.2KiB in use in bin. 5.0KiB client-requested in use in bin.
# 2024-03-03 15:21:21.642675: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 12, Chunks in use: 12. 6.0KiB allocated for chunks. 6.0KiB in use in bin. 5.8KiB client-requested in use in bin.
# 2024-03-03 15:21:21.642678: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 24, Chunks in use: 24. 24.8KiB allocated for chunks. 24.8KiB in use in bin. 23.8KiB client-requested in use in bin.
# 2024-03-03 15:21:21.642682: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-03 15:21:21.642685: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 5, Chunks in use: 5. 25.5KiB allocated for chunks. 25.5KiB in use in bin. 25.1KiB client-requested in use in bin.
# 2024-03-03 15:21:21.642688: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 1, Chunks in use: 1. 8.2KiB allocated for chunks. 8.2KiB in use in bin. 5.1KiB client-requested in use in bin.
# 2024-03-03 15:21:21.642690: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-03 15:21:21.642694: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 2, Chunks in use: 2. 108.0KiB allocated for chunks. 108.0KiB in use in bin. 108.0KiB client-requested in use in bin.
# 2024-03-03 15:21:21.642697: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 1, Chunks in use: 1. 77.2KiB allocated for chunks. 77.2KiB in use in bin. 54.0KiB client-requested in use in bin.
# 2024-03-03 15:21:21.642700: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 4, Chunks in use: 3. 816.2KiB allocated for chunks. 648.0KiB in use in bin. 648.0KiB client-requested in use in bin.
# 2024-03-03 15:21:21.642703: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 3, Chunks in use: 3. 768.0KiB allocated for chunks. 768.0KiB in use in bin. 768.0KiB client-requested in use in bin.
# 2024-03-03 15:21:21.642706: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 2, Chunks in use: 2. 1.69MiB allocated for chunks. 1.69MiB in use in bin. 1.69MiB client-requested in use in bin.
# 2024-03-03 15:21:21.642709: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 1, Chunks in use: 1. 1.19MiB allocated for chunks. 1.19MiB in use in bin. 864.0KiB client-requested in use in bin.
# 2024-03-03 15:21:21.642712: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-03 15:21:21.642715: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-03 15:21:21.642718: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 2, Chunks in use: 2. 25.00MiB allocated for chunks. 25.00MiB in use in bin. 25.00MiB client-requested in use in bin.
# 2024-03-03 15:21:21.642721: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 1, Chunks in use: 1. 24.16MiB allocated for chunks. 24.16MiB in use in bin. 12.50MiB client-requested in use in bin.
# 2024-03-03 15:21:21.642723: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-03 15:21:21.642735: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-03 15:21:21.642738: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 2, Chunks in use: 1. 468.75MiB allocated for chunks. 234.38MiB in use in bin. 234.38MiB client-requested in use in bin.
# 2024-03-03 15:21:21.642741: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 2, Chunks in use: 1. 1.68GiB allocated for chunks. 1.22GiB in use in bin. 1.22GiB client-requested in use in bin.
# 2024-03-03 15:21:21.642744: I external/local_tsl/tsl/framework/bfc_allocator.cc:1062] Bin for 1.22GiB was 256.00MiB, Chunk State:
# 2024-03-03 15:21:21.642749: I external/local_tsl/tsl/framework/bfc_allocator.cc:1068]   Size: 475.86MiB | Requested Size: 0B | in_use: 0 | bin_num: 20, prev:   Size: 1.22GiB | Requested Size: 1.22GiB | in_use: 1 | bin_num: -1
# 2024-03-03 15:21:21.642751: I external/local_tsl/tsl/framework/bfc_allocator.cc:1075] Next region of size 2357670656
# 2024-03-03 15:21:21.642754: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00000 of size 256 next 1
# 2024-03-03 15:21:21.642756: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00100 of size 1280 next 2
# 2024-03-03 15:21:21.642758: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00600 of size 256 next 3
# 2024-03-03 15:21:21.642760: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00700 of size 256 next 4
# 2024-03-03 15:21:21.642762: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00800 of size 256 next 6
# 2024-03-03 15:21:21.642764: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00900 of size 256 next 7
# 2024-03-03 15:21:21.642766: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00a00 of size 256 next 5
# 2024-03-03 15:21:21.642768: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00b00 of size 256 next 8
# 2024-03-03 15:21:21.642770: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00c00 of size 256 next 11
# 2024-03-03 15:21:21.642772: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00d00 of size 256 next 12
# 2024-03-03 15:21:21.642774: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00e00 of size 256 next 13
# 2024-03-03 15:21:21.642775: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00f00 of size 256 next 14
# 2024-03-03 15:21:21.642777: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01000 of size 256 next 15
# 2024-03-03 15:21:21.642779: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01100 of size 256 next 18
# 2024-03-03 15:21:21.642781: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01200 of size 256 next 16
# 2024-03-03 15:21:21.642783: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c
: I external/local_tsl/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                      2357670708
# InUse:                      1612763136
# MaxInUse:                   1678501120
# NumAllocs:                         190
# MaxAllocSize:               1310720000
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2024-03-03 15:21:21.643090: W external/local_tsl/tsl/framework/bfc_allocator.cc:497] ***_________*******************************************************************_____________________
# 2024-03-03 15:21:21.643115: W tensorflow/core/framework/op_kernel.cc:1839] OP_REQUIRES failed at fused_batch_norm_op.cc:1565 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[40,16,20,25600] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /tmp/ipykernel_8850/2925731155.py in <module>
#       1 print("Total Params:", conv_3d9_model.count_params())
# ----> 2 history_model9=conv_3d9.train_model(conv_3d9_model,augment_data=True)
#
# /tmp/ipykernel_8850/1912833249.py in train_model(self, model, augment_data)
#     124             validation_steps = (self.num_val_sequences//self.batch_size) + 1
#     125
# --> 126         history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=self.num_epochs, verbose=1,
#     127                             callbacks=callbacks_list, validation_data=val_generator,
#     128                             validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
#
# ~/.local/lib/python3.10/site-packages/keras/src/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2911             stacklevel=2,
#    2912         )
# -> 2913         return self.fit(
#    2914             generator,
#    2915             steps_per_epoch=steps_per_epoch,
#
# ~/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node sequential/batch_normalization/FusedBatchNormV3 defined at (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/usr/lib/python3/dist-packages/ipykernel_launcher.py", line 16, in <module>
#
#   File "/usr/lib/python3/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#
#   File "/usr/lib/python3/dist-packages/ipykernel/kernelapp.py", line 677, in start
#
#   File "/usr/lib/python3/dist-packages/tornado/platform/asyncio.py", line 199, in start
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/usr/lib/python3/dist-packages/ipykernel/kernelbase.py", line 461, in dispatch_queue
#
#   File "/usr/lib/python3/dist-packages/ipykernel/kernelbase.py", line 450, in process_one
#
#   File "/usr/lib/python3/dist-packages/ipykernel/kernelbase.py", line 357, in dispatch_shell
#
#   File "/usr/lib/python3/dist-packages/ipykernel/kernelbase.py", line 652, in execute_request
#
#   File "/usr/lib/python3/dist-packages/ipykernel/ipkernel.py", line 353, in do_execute
#
#   File "/usr/lib/python3/dist-packages/ipykernel/zmqshell.py", line 532, in run_cell
#
#   File "/usr/lib/python3/dist-packages/IPython/core/interactiveshell.py", line 2914, in run_cell
#
#   File "/usr/lib/python3/dist-packages/IPython/core/interactiveshell.py", line 2960, in _run_cell
#
#   File "/usr/lib/python3/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#
#   File "/usr/lib/python3/dist-packages/IPython/core/interactiveshell.py", line 3185, in run_cell_async
#
#   File "/usr/lib/python3/dist-packages/IPython/core/interactiveshell.py", line 3377, in run_ast_nodes
#
#   File "/usr/lib/python3/dist-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#
#   File "/tmp/ipykernel_8850/2925731155.py", line 2, in <module>
#
#   File "/tmp/ipykernel_8850/1912833249.py", line 126, in train_model
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 2913, in fit_generator
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1807, in fit
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1401, in train_function
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1384, in step_function
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1373, in run_step
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1150, in train_step
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 590, in __call__
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/engine/sequential.py", line 398, in call
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/engine/functional.py", line 515, in call
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/engine/functional.py", line 672, in _run_internal_graph
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/layers/normalization/batch_normalization.py", line 597, in call
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/layers/normalization/batch_normalization.py", line 990, in _fused_batch_norm
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/utils/control_flow_util.py", line 108, in smart_cond
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/layers/normalization/batch_normalization.py", line 964, in _fused_batch_norm_training
#
# OOM when allocating tensor with shape[40,16,20,25600] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node sequential/batch_normalization/FusedBatchNormV3}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_3423]

# %%
plot(history_model9)

# %% [markdown]
# ## Model 10 with Augmentation
# ### (2,2,2) Filter & 120x120 Image resolution - similar to Model 3

# %%
class ModelConv3D10(ModelBuilderMoreAugmentation):

    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam(learning_rate=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d10=ModelConv3D10()
conv_3d10.initialize_path(project_folder)
conv_3d10.initialize_image_properties(image_height=120,image_width=120)
conv_3d10.initialize_hyperparams(frames_to_sample=16,batch_size=30,num_epochs=25)
conv_3d10_model=conv_3d10.define_model(filtersize=(2,2,2),dense_neurons=256,dropout=0.5)
conv_3d10_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_8 (Conv3D)           (None, 16, 120, 120, 16   400
#                              )
#
#  activation_8 (Activation)   (None, 16, 120, 120, 16   0
#                              )
#
#  batch_normalization_12 (Ba  (None, 16, 120, 120, 16   64
#  tchNormalization)           )
#
#  max_pooling3d_8 (MaxPoolin  (None, 8, 60, 60, 16)     0
#  g3D)
#
#  conv3d_9 (Conv3D)           (None, 8, 60, 60, 32)     4128
#
#  activation_9 (Activation)   (None, 8, 60, 60, 32)     0
#
#  batch_normalization_13 (Ba  (None, 8, 60, 60, 32)     128
#  tchNormalization)
#
#  max_pooling3d_9 (MaxPoolin  (None, 4, 30, 30, 32)     0
#  g3D)
#
#  conv3d_10 (Conv3D)          (None, 4, 30, 30, 64)     16448
#
#  activation_10 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_14 (Ba  (None, 4, 30, 30, 64)     256
#  tchNormalization)
#
#  max_pooling3d_10 (MaxPooli  (None, 2, 15, 15, 64)     0
#  ng3D)
#
#  conv3d_11 (Conv3D)          (None, 2, 15, 15, 128)    65664
#
#  activation_11 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_15 (Ba  (None, 2, 15, 15, 128)    512
#  tchNormalization)
#
#  max_pooling3d_11 (MaxPooli  (None, 1, 7, 7, 128)      0
#  ng3D)
#
#  flatten_2 (Flatten)         (None, 6272)              0
#
#  dense_6 (Dense)             (None, 256)               1605888
#
#  batch_normalization_16 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 256)               65792
#
#  batch_normalization_17 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_8 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 1762613 (6.72 MB)
# Trainable params: 1761109 (6.72 MB)
# Non-trainable params: 1504 (5.88 KB)
# _________________________________________________________________

# %%
print("Total Params:", conv_3d10_model.count_params())
history_model10=conv_3d10.train_model(conv_3d10_model,augment_data=True)
# Out:
# Total Params: 1762613
# Epoch 1/25
# 2024-03-03 15:22:09.876952: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 859.75MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-03 15:22:21.275253: W external/local_tsl/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 843.75MiB (rounded to 884736000)requested by op sequential_2/batch_normalization_12/FusedBatchNormV3-0-0-TransposeNCDHWToNDHWC-LayoutOptimizer
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2024-03-03 15:22:21.275299: I external/local_tsl/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2024-03-03 15:22:21.275309: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 138, Chunks in use: 138. 34.5KiB allocated for chunks. 34.5KiB in use in bin. 10.3KiB client-requested in use in bin.
# 2024-03-03 15:22:21.275312: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 23, Chunks in use: 23. 11.5KiB allocated for chunks. 11.5KiB in use in bin. 11.5KiB client-requested in use in bin.
# 2024-03-03 15:22:21.275316: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 50, Chunks in use: 49. 53.5KiB allocated for chunks. 52.5KiB in use in bin. 50.7KiB client-requested in use in bin.
# 2024-03-03 15:22:21.275319: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-03 15:22:21.275322: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 8, Chunks in use: 8. 40.5KiB allocated for chunks. 40.5KiB in use in bin. 40.1KiB client-requested in use in bin.
# 2024-03-03 15:22:21.275325: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 2, Chunks in use: 1. 18.5KiB allocated for chunks. 8.2KiB in use in bin. 5.1KiB client-requested in use in bin.
# 2024-03-03 15:22:21.275329: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 5, Chunks in use: 3. 104.0KiB allocated for chunks. 53.8KiB in use in bin. 48.0KiB client-requested in use in bin.
# 2024-03-03 15:22:21.275332: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 2, Chunks in use: 2. 108.0KiB allocated for chunks. 108.0KiB in use in bin. 108.0KiB client-requested in use in bin.
# 2024-03-03 15:22:21.275335: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 5, Chunks in use: 4. 386.0KiB allocated for chunks. 322.0KiB in use in bin. 246.0KiB client-requested in use in bin.
# 2024-03-03 15:22:21.275338: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 4, Chunks in use: 3. 840.0KiB allocated for chunks. 648.0KiB in use in bin. 648.0KiB client-requested in use in bin.
# 2024-03-03 15:22:21.275341: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 9, Chunks in use: 9. 2.38MiB allocated for chunks. 2.38MiB in use in bin. 2.25MiB client-requested in use in bin.
# 2024-03-03 15:22:21.275343: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 3, Chunks in use: 2. 2.19MiB allocated for chunks. 1.69MiB in use in bin. 1.69MiB client-requested in use in bin.
# 2024-03-03 15:22:21.275346: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 1, Chunks in use: 1. 1.19MiB allocated for chunks. 1.19MiB in use in bin. 864.0KiB client-requested in use in bin.
# 2024-03-03 15:22:21.275349: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-03 15:22:21.275352: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 4, Chunks in use: 2. 23.50MiB allocated for chunks. 12.25MiB in use in bin. 12.25MiB client-requested in use in bin.
# 2024-03-03 15:22:21.275355: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 3, Chunks in use: 3. 36.50MiB allocated for chunks. 36.50MiB in use in bin. 31.12MiB client-requested in use in bin.
# 2024-03-03 15:22:21.275358: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 1, Chunks in use: 1. 24.16MiB allocated for chunks. 24.16MiB in use in bin. 12.50MiB client-requested in use in bin.
# 2024-03-03 15:22:21.275361: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-03 15:22:21.275369: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-03 15:22:21.275372: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 3, Chunks in use: 1. 469.48MiB allocated for chunks. 158.20MiB in use in bin. 158.20MiB client-requested in use in bin.
# 2024-03-03 15:22:21.275375: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 2, Chunks in use: 2. 1.65GiB allocated for chunks. 1.65GiB in use in bin. 1.65GiB client-requested in use in bin.
# 2024-03-03 15:22:21.275378: I external/local_tsl/tsl/framework/bfc_allocator.cc:1062] Bin for 843.75MiB was 256.00MiB, Chunk State:
# 2024-03-03 15:22:21.275380: I external/local_tsl/tsl/framework/bfc_allocator.cc:1075] Next region of size 2357670656
# 2024-03-03 15:22:21.275384: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00000 of size 256 next 1
# 2024-03-03 15:22:21.275387: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00100 of size 1280 next 2
# 2024-03-03 15:22:21.275389: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00600 of size 256 next 3
# 2024-03-03 15:22:21.275391: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00700 of size 256 next 4
# 2024-03-03 15:22:21.275392: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00800 of size 256 next 6
# 2024-03-03 15:22:21.275394: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00900 of size 256 next 7
# 2024-03-03 15:22:21.275396: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00a00 of size 256 next 5
# 2024-03-03 15:22:21.275398: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00b00 of size 256 next 8
# 2024-03-03 15:22:21.275400: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00c00 of size 256 next 11
# 2024-03-03 15:22:21.275402: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00d00 of size 256 next 12
# 2024-03-03 15:22:21.275404: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00e00 of size 256 next 13
# 2024-03-03 15:22:21.275406: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00f00 of size 256 next 14
# 2024-03-03 15:22:21.275408: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01000 of size 256 next 15
# 2024-03-03 15:22:21.275410: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01100 of size 256 next 18
# 2024-03-03 15:22:21.275411: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01200 of size 256 next 16
# 2024-03-03 15:22:21.275413: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01300 of size 256 next 17
# 2024-03-03 15:22:21.275415: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01400 of size 256 next 21
# 2024-03-03 15:22:21.275417: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01500 of size 256 next 22
# 2024-03-03 15:22:21.275419: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01600 of size 256 next 23
# 2024-03-03 15:22:21.275421: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01700 of size 256 next 24
# 2024-03-03 15:22:21.275423: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01800 of size 256 next 27
# 2024-03-03 15:22:21.275426: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01900 of size 256 next 25
# 2024-03-03 15:22:21.275428: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01a00 of size 256 next 26
# 2024-03-03 15:22:21.275429: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01b00 of size 256 next 30
# 2024-03-03 15:22:21.275432: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01c00 of size 256 next 31
# 2024-03-03 15:22:21.275434: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01d00 of size 256 next 32
# 2024-03-03 15:22:21.275436: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01e00 of size 256 next 33
# 2024-03-03 15:22:21.275438: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01f00 of size 512 next 36
# 2024-03-03 15:22:21.275440: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c02100 of size 512 next 34
# 2024-03-03 15:22:21.275442: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c02300 of size 512 next 35
# 2024-03-03 15:22:21.275444: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c02500 of size 512 next 39
# 2024-03-03 15:22:21.275446: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c02700 of size 512 next 40
# 2024-03-03 15:22:21.275448: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c02900 of size 256 next 41
# 2024-03-03 15:22:21.275450: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c02a00 of size 256 next 42
# 2024-03-03 15:22:21.275452: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c02b00 of size 1024 next 45
# 2024-03-03 15:22:21.275454: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c02f00 of size 1536 next 9
# 2024-03-03 15:22:21.275456: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c03500 of size 5376 next 10
# 2024-03-03 15:22:21.275458: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c04a00 of size 1024 next 43
# 2024-03-03 15:22:21.275460: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c04e00 of size 1024 next 44
# 2024-03-03 15:22:21.275462: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c05200 of size 1024 next 48
# 2024-03-03 15:22:21.275464: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c05600 of size 256 next 49
# 2024-03-03 15:22:21.275466: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c05700 of size 256 next 50
# 2024-03-03 15:22:21.275468: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c05800 of size 1024 next 51
# 2024-03-03 15:22:21.275470: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c05c00 of size 1024 next 52
# 2024-03-03 15:22:21.275472: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c06000 of size 1024 next 55
# 2024-03-03 15:22:21.275474: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c06400 of size 1024 next 56
# 2024-03-03 15:22:21.275476: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c0
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /tmp/ipykernel_8850/82116002.py in <module>
#       1 print("Total Params:", conv_3d10_model.count_params())
# ----> 2 history_model10=conv_3d10.train_model(conv_3d10_model,augment_data=True)
#
# /tmp/ipykernel_8850/1912833249.py in train_model(self, model, augment_data)
#     124             validation_steps = (self.num_val_sequences//self.batch_size) + 1
#     125
# --> 126         history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=self.num_epochs, verbose=1,
#     127                             callbacks=callbacks_list, validation_data=val_generator,
#     128                             validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
#
# ~/.local/lib/python3.10/site-packages/keras/src/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2911             stacklevel=2,
#    2912         )
# -> 2913         return self.fit(
#    2914             generator,
#    2915             steps_per_epoch=steps_per_epoch,
#
# ~/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node sequential_2/batch_normalization_12/FusedBatchNormV3-0-0-TransposeNCDHWToNDHWC-LayoutOptimizer defined at (most recent call last):
# <stack traces unavailable>
# OOM when allocating tensor with shape[60,16,120,120,16] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node sequential_2/batch_normalization_12/FusedBatchNormV3-0-0-TransposeNCDHWToNDHWC-LayoutOptimizer}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_7312]
# 6800 of size 1024 next 57
# 2024-03-03 15:22:21.275478: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c06c00 of size 256 next 58
# 2024-03-03 15:22:21.275480: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c06d00 of size 256 next 59
# 2024-03-03 15:22:21.275482: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c06e00 of size 256 next 61
# 2024-03-03 15:22:21.275484: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c06f00 of size 256 next 62
# 2024-03-03 15:22:21.275486: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c07000 of size 256 next 60
# 2024-03-03 15:22:21.275488: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c07100 of size 256 next 63
# 2024-03-03 15:22:21.275490: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c07200 of size 256 next 66
# 2024-03-03 15:22:21.275492: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c07300 of size 256 next 67
# 2024-03-03 15:22:21.275494: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c07400 of size 256 next 71
# 2024-03-03 15:22:21.275496: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c07500 of size 256 next 72
# 2024-03-03 15:22:21.275498: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c07600 of size 256 next 68
# 2024-03-03 15:22:21.275500: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c
W external/local_tsl/tsl/framework/bfc_allocator.cc:497] *****______***********************************************************************************______
# 2024-03-03 15:22:21.276195: W tensorflow/core/framework/op_kernel.cc:1839] OP_REQUIRES failed at transpose_op.cc:184 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[60,16,120,120,16] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc

# %%
plot(history_model10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_8850/2150336276.py in <module>
# ----> 1 plot(history_model10)
#
# NameError: name 'history_model10' is not defined

# %% [markdown]
# ## Model 11 with Augmentation
# ### Adding more layers - Similar to model 4

# %%
class ModelConv3D11(ModelBuilderMoreAugmentation):

    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling3D(pool_size=(2, 2, 2)))


        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam(learning_rate=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d11=ModelConv3D11()
conv_3d11.initialize_path(project_folder)
conv_3d11.initialize_image_properties(image_height=120,image_width=120)
conv_3d11.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=25)
conv_3d11_model=conv_3d11.define_model(filtersize=(3,3,3),dense_neurons=256,dropout=0.5)
conv_3d11_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_12 (Conv3D)          (None, 16, 120, 120, 16   1312
#                              )
#
#  activation_12 (Activation)  (None, 16, 120, 120, 16   0
#                              )
#
#  batch_normalization_18 (Ba  (None, 16, 120, 120, 16   64
#  tchNormalization)           )
#
#  conv3d_13 (Conv3D)          (None, 16, 120, 120, 16   6928
#                              )
#
#  activation_13 (Activation)  (None, 16, 120, 120, 16   0
#                              )
#
#  batch_normalization_19 (Ba  (None, 16, 120, 120, 16   64
#  tchNormalization)           )
#
#  max_pooling3d_12 (MaxPooli  (None, 8, 60, 60, 16)     0
#  ng3D)
#
#  conv3d_14 (Conv3D)          (None, 8, 60, 60, 32)     13856
#
#  activation_14 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_20 (Ba  (None, 8, 60, 60, 32)     128
#  tchNormalization)
#
#  conv3d_15 (Conv3D)          (None, 8, 60, 60, 32)     27680
#
#  activation_15 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_21 (Ba  (None, 8, 60, 60, 32)     128
#  tchNormalization)
#
#  max_pooling3d_13 (MaxPooli  (None, 4, 30, 30, 32)     0
#  ng3D)
#
#  conv3d_16 (Conv3D)          (None, 4, 30, 30, 64)     55360
#
#  activation_16 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_22 (Ba  (None, 4, 30, 30, 64)     256
#  tchNormalization)
#
#  conv3d_17 (Conv3D)          (None, 4, 30, 30, 64)     110656
#
#  activation_17 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_23 (Ba  (None, 4, 30, 30, 64)     256
#  tchNormalization)
#
#  max_pooling3d_14 (MaxPooli  (None, 2, 15, 15, 64)     0
#  ng3D)
#
#  conv3d_18 (Conv3D)          (None, 2, 15, 15, 128)    221312
#
#  activation_18 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_24 (Ba  (None, 2, 15, 15, 128)    512
#  tchNormalization)
#
#  conv3d_19 (Conv3D)          (None, 2, 15, 15, 128)    442496
#
#  activation_19 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_25 (Ba  (None, 2, 15, 15, 128)    512
#  tchNormalization)
#
#  max_pooling3d_15 (MaxPooli  (None, 1, 7, 7, 128)      0
#  ng3D)
#
#  flatten_3 (Flatten)         (None, 6272)              0
#
#  dense_9 (Dense)             (None, 256)               1605888
#
#  batch_normalization_26 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_10 (Dense)            (None, 256)               65792
#
#  batch_normalization_27 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_11 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 2556533 (9.75 MB)
# Trainable params: 2554549 (9.74 MB)
# Non-trainable params: 1984 (7.75 KB)
# _________________________________________________________________

# %%
print("Total Params:", conv_3d11_model.count_params())
history_model11=conv_3d11.train_model(conv_3d11_model,augment_data=True)
# Out:
# Total Params: 2556533
# Epoch 1/25
# 2024-03-03 15:23:08.423392: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 578.50MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-03 15:23:24.954860: W external/local_tsl/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 562.50MiB (rounded to 589824000)requested by op sequential_3/batch_normalization_19/FusedBatchNormV3
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2024-03-03 15:23:24.954912: I external/local_tsl/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2024-03-03 15:23:24.954922: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 227, Chunks in use: 227. 56.8KiB allocated for chunks. 56.8KiB in use in bin. 19.9KiB client-requested in use in bin.
# 2024-03-03 15:23:24.954925: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 46, Chunks in use: 45. 23.0KiB allocated for chunks. 22.5KiB in use in bin. 22.3KiB client-requested in use in bin.
# 2024-03-03 15:23:24.954928: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 71, Chunks in use: 71. 74.5KiB allocated for chunks. 74.5KiB in use in bin. 72.3KiB client-requested in use in bin.
# 2024-03-03 15:23:24.954932: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-03 15:23:24.954935: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 14, Chunks in use: 14. 73.2KiB allocated for chunks. 73.2KiB in use in bin. 70.3KiB client-requested in use in bin.
# 2024-03-03 15:23:24.954938: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 1, Chunks in use: 1. 8.2KiB allocated for chunks. 8.2KiB in use in bin. 5.1KiB client-requested in use in bin.
# 2024-03-03 15:23:24.954941: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 6, Chunks in use: 5. 134.8KiB allocated for chunks. 108.2KiB in use in bin. 102.0KiB client-requested in use in bin.
# 2024-03-03 15:23:24.954945: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 4, Chunks in use: 4. 199.0KiB allocated for chunks. 199.0KiB in use in bin. 189.0KiB client-requested in use in bin.
# 2024-03-03 15:23:24.954948: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 9, Chunks in use: 9. 811.0KiB allocated for chunks. 811.0KiB in use in bin. 678.0KiB client-requested in use in bin.
# 2024-03-03 15:23:24.954951: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 4, Chunks in use: 4. 864.0KiB allocated for chunks. 864.0KiB in use in bin. 864.0KiB client-requested in use in bin.
# 2024-03-03 15:23:24.954954: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 17, Chunks in use: 17. 5.02MiB allocated for chunks. 5.02MiB in use in bin. 4.69MiB client-requested in use in bin.
# 2024-03-03 15:23:24.954957: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 5, Chunks in use: 5. 4.22MiB allocated for chunks. 4.22MiB in use in bin. 4.22MiB client-requested in use in bin.
# 2024-03-03 15:23:24.954960: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 3, Chunks in use: 3. 4.62MiB allocated for chunks. 4.62MiB in use in bin. 4.22MiB client-requested in use in bin.
# 2024-03-03 15:23:24.954963: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 1, Chunks in use: 1. 2.75MiB allocated for chunks. 2.75MiB in use in bin. 1.69MiB client-requested in use in bin.
# 2024-03-03 15:23:24.954966: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 5, Chunks in use: 5. 30.62MiB allocated for chunks. 30.62MiB in use in bin. 30.62MiB client-requested in use in bin.
# 2024-03-03 15:23:24.954969: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 3, Chunks in use: 3. 36.50MiB allocated for chunks. 36.50MiB in use in bin. 31.12MiB client-requested in use in bin.
# 2024-03-03 15:23:24.954974: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 1, Chunks in use: 1. 24.16MiB allocated for chunks. 24.16MiB in use in bin. 12.50MiB client-requested in use in bin.
# 2024-03-03 15:23:24.954976: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-03 15:23:24.954980: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 2, Chunks in use: 1. 210.94MiB allocated for chunks. 105.47MiB in use in bin. 105.47MiB client-requested in use in bin.
# 2024-03-03 15:23:24.954982: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 1, Chunks in use: 0. 239.92MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-03 15:23:24.954985: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 3, Chunks in use: 3. 1.65GiB allocated for chunks. 1.65GiB in use in bin. 1.65GiB client-requested in use in bin.
# 2024-03-03 15:23:24.954989: I external/local_tsl/tsl/framework/bfc_allocator.cc:1062] Bin for 562.50MiB was 256.00MiB, Chunk State:
# 2024-03-03 15:23:24.954991: I external/local_tsl/tsl/framework/bfc_allocator.cc:1075] Next region of size 2357670656
# 2024-03-03 15:23:24.954995: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00000 of size 256 next 1
# 2024-03-03 15:23:24.954997: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00100 of size 1280 next 2
# 2024-03-03 15:23:24.954999: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00600 of size 256 next 3
# 2024-03-03 15:23:24.955001: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00700 of size 256 next 4
# 2024-03-03 15:23:24.955003: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00800 of size 256 next 6
# 2024-03-03 15:23:24.955005: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00900 of size 256 next 7
# 2024-03-03 15:23:24.955007: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c
: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c07300 of size 256 next 67
# 2024-03-03 15:23:24.955107: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c07400 of size 256 next 71
# 2024-03-03 15:23:24.955109: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c07500 of size 256 next 72
# 2024-03-03 15:23:24.955111: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c07600 of size 256 next 68
# 2024-03-03 15:23:24.955113: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c07700 of size 256 next 69
# 2024-03-03 15:23:24.955115: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c07800 of size 8448 next 64
# 2024-03-03 15:23:24.955117: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c09900 of size 5120 next 65
# 2024-03-03 15:23:24.955119: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c0ad00 of size 5376 next 70
# 2024-03-03 15:23:24.955121: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c0c200 of size 256 next 73
# 2024-03-03 15:23:24.955123: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c0c300 of size 256 next 74
# 2024-03-03 15:23:24.955125: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c0c400 of size 256 next 75
# 2024-03-03 15:23:24.955127: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c0c500 of size 79104 next 20
# 2024-03-03 15:23:24.955129: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c1fa00 of size 5529
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /tmp/ipykernel_8850/3369474447.py in <module>
#       1 print("Total Params:", conv_3d11_model.count_params())
# ----> 2 history_model11=conv_3d11.train_model(conv_3d11_model,augment_data=True)
#
# /tmp/ipykernel_8850/1912833249.py in train_model(self, model, augment_data)
#     124             validation_steps = (self.num_val_sequences//self.batch_size) + 1
#     125
# --> 126         history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=self.num_epochs, verbose=1,
#     127                             callbacks=callbacks_list, validation_data=val_generator,
#     128                             validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
#
# ~/.local/lib/python3.10/site-packages/keras/src/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2911             stacklevel=2,
#    2912         )
# -> 2913         return self.fit(
#    2914             generator,
#    2915             steps_per_epoch=steps_per_epoch,
#
# ~/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node sequential_3/batch_normalization_19/FusedBatchNormV3 defined at (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/usr/lib/python3/dist-packages/ipykernel_launcher.py", line 16, in <module>
#
#   File "/usr/lib/python3/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#
#   File "/usr/lib/python3/dist-packages/ipykernel/kernelapp.py", line 677, in start
#
#   File "/usr/lib/python3/dist-packages/tornado/platform/asyncio.py", line 199, in start
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/usr/lib/python3/dist-packages/ipykernel/kernelbase.py", line 461, in dispatch_queue
#
#   File "/usr/lib/python3/dist-packages/ipykernel/kernelbase.py", line 450, in process_one
#
#   File "/usr/lib/python3/dist-packages/ipykernel/kernelbase.py", line 357, in dispatch_shell
#
#   File "/usr/lib/python3/dist-packages/ipykernel/kernelbase.py", line 652, in execute_request
#
#   File "/usr/lib/python3/dist-packages/ipykernel/ipkernel.py", line 353, in do_execute
#
#   File "/usr/lib/python3/dist-packages/ipykernel/zmqshell.py", line 532, in run_cell
#
#   File "/usr/lib/python3/dist-packages/IPython/core/interactiveshell.py", line 2914, in run_cell
#
#   File "/usr/lib/python3/dist-packages/IPython/core/interactiveshell.py", line 2960, in _run_cell
#
#   File "/usr/lib/python3/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#
#   File "/usr/lib/python3/dist-packages/IPython/core/interactiveshell.py", line 3185, in run_cell_async
#
#   File "/usr/lib/python3/dist-packages/IPython/core/interactiveshell.py", line 3377, in run_ast_nodes
#
#   File "/usr/lib/python3/dist-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#
#   File "/tmp/ipykernel_8850/3369474447.py", line 2, in <module>
#
#   File "/tmp/ipykernel_8850/1912833249.py", line 126, in train_model
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 2913, in fit_generator
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1807, in fit
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1401, in train_function
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1384, in step_function
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1373, in run_step
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1150, in train_step
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 590, in __call__
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/engine/sequential.py", line 398, in call
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/engine/functional.py", line 515, in call
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/engine/functional.py", line 672, in _run_internal_graph
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/layers/normalization/batch_normalization.py", line 597, in call
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/layers/normalization/batch_normalization.py", line 990, in _fused_batch_norm
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/utils/control_flow_util.py", line 108, in smart_cond
#
#   File "/home/amit/.local/lib/python3.10/site-packages/keras/src/layers/normalization/batch_normalization.py", line 964, in _fused_batch_norm_training
#
# OOM when allocating tensor with shape[40,16,16,14400] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{
W tensorflow/core/framework/op_kernel.cc:1839] OP_REQUIRES failed at fused_batch_norm_op.cc:1565 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[40,16,16,14400] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc

# %%
plot(history_model11)

# %% [markdown]
# ## Model 12 with Augmentation
# ### Adding dropouts - Similar to Model 5

# %%
class ModelConv3D12(ModelBuilderMoreAugmentation):

    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model.add(Dropout(dropout))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model.add(Dropout(dropout))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model.add(Dropout(dropout))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model.add(Dropout(dropout))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam(learning_rate=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d12=ModelConv3D12()
conv_3d12.initialize_path(project_folder)
conv_3d12.initialize_image_properties(image_height=120,image_width=120)
conv_3d12.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=25)
conv_3d12_model=conv_3d12.define_model(filtersize=(3,3,3),dense_neurons=256,dropout=0.25)
conv_3d12_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_28 (Conv3D)          (None, 16, 120, 120, 16   1312
#                              )
#
#  activation_28 (Activation)  (None, 16, 120, 120, 16   0
#                              )
#
#  batch_normalization_38 (Ba  (None, 16, 120, 120, 16   64
#  tchNormalization)           )
#
#  conv3d_29 (Conv3D)          (None, 16, 120, 120, 16   6928
#                              )
#
#  activation_29 (Activation)  (None, 16, 120, 120, 16   0
#                              )
#
#  batch_normalization_39 (Ba  (None, 16, 120, 120, 16   64
#  tchNormalization)           )
#
#  max_pooling3d_20 (MaxPooli  (None, 8, 60, 60, 16)     0
#  ng3D)
#
#  dropout_14 (Dropout)        (None, 8, 60, 60, 16)     0
#
#  conv3d_30 (Conv3D)          (None, 8, 60, 60, 32)     13856
#
#  activation_30 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_40 (Ba  (None, 8, 60, 60, 32)     128
#  tchNormalization)
#
#  conv3d_31 (Conv3D)          (None, 8, 60, 60, 32)     27680
#
#  activation_31 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_41 (Ba  (None, 8, 60, 60, 32)     128
#  tchNormalization)
#
#  max_pooling3d_21 (MaxPooli  (None, 4, 30, 30, 32)     0
#  ng3D)
#
#  dropout_15 (Dropout)        (None, 4, 30, 30, 32)     0
#
#  conv3d_32 (Conv3D)          (None, 4, 30, 30, 64)     55360
#
#  activation_32 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_42 (Ba  (None, 4, 30, 30, 64)     256
#  tchNormalization)
#
#  conv3d_33 (Conv3D)          (None, 4, 30, 30, 64)     110656
#
#  activation_33 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_43 (Ba  (None, 4, 30, 30, 64)     256
#  tchNormalization)
#
#  max_pooling3d_22 (MaxPooli  (None, 2, 15, 15, 64)     0
#  ng3D)
#
#  dropout_16 (Dropout)        (None, 2, 15, 15, 64)     0
#
#  conv3d_34 (Conv3D)          (None, 2, 15, 15, 128)    221312
#
#  activation_34 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_44 (Ba  (None, 2, 15, 15, 128)    512
#  tchNormalization)
#
#  conv3d_35 (Conv3D)          (None, 2, 15, 15, 128)    442496
#
#  activation_35 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_45 (Ba  (None, 2, 15, 15, 128)    512
#  tchNormalization)
#
#  max_pooling3d_23 (MaxPooli  (None, 1, 7, 7, 128)      0
#  ng3D)
#
#  dropout_17 (Dropout)        (None, 1, 7, 7, 128)      0
#
#  flatten_5 (Flatten)         (None, 6272)              0
#
#  dense_15 (Dense)            (None, 256)               1605888
#
#  batch_normalization_46 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_18 (Dropout)        (None, 256)               0
#
#  dense_16 (Dense)            (None, 256)               65792
#
#  batch_normalization_47 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_19 (Dropout)        (None, 256)               0
#
#  dense_17 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 2556533 (9.75 MB)
# Trainable params: 2554549 (9.74 MB)
# Non-trainable params: 1984 (7.75 KB)
# _________________________________________________________________

# %%
print("Total Params:", conv_3d12_model.count_params())
history_model12=conv_3d12.train_model(conv_3d12_model,augment_data=True)

# %%
plot(history_model12)

# %% [markdown]
# Model is overfitting badly !!

# %% [markdown]
# ## Model 13 with Augmentation
# ### Reducing network parameters - Similar to Model 6

# %%
class ModelConv3D13(ModelBuilderMoreAugmentation):

    def define_model(self,dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam(learning_rate=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d13=ModelConv3D13()
conv_3d13.initialize_path(project_folder)
conv_3d13.initialize_image_properties(image_height=100,image_width=100)
conv_3d13.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=25)
conv_3d13_model=conv_3d13.define_model(dense_neurons=128,dropout=0.25)
conv_3d13_model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_40 (Conv3D)          (None, 16, 100, 100, 16   1312
#                              )
#
#  activation_40 (Activation)  (None, 16, 100, 100, 16   0
#                              )
#
#  batch_normalization_54 (Ba  (None, 16, 100, 100, 16   64
#  tchNormalization)           )
#
#  max_pooling3d_28 (MaxPooli  (None, 8, 50, 50, 16)     0
#  ng3D)
#
#  conv3d_41 (Conv3D)          (None, 8, 50, 50, 32)     4128
#
#  activation_41 (Activation)  (None, 8, 50, 50, 32)     0
#
#  batch_normalization_55 (Ba  (None, 8, 50, 50, 32)     128
#  tchNormalization)
#
#  max_pooling3d_29 (MaxPooli  (None, 4, 25, 25, 32)     0
#  ng3D)
#
#  conv3d_42 (Conv3D)          (None, 4, 25, 25, 64)     16448
#
#  activation_42 (Activation)  (None, 4, 25, 25, 64)     0
#
#  batch_normalization_56 (Ba  (None, 4, 25, 25, 64)     256
#  tchNormalization)
#
#  max_pooling3d_30 (MaxPooli  (None, 2, 12, 12, 64)     0
#  ng3D)
#
#  conv3d_43 (Conv3D)          (None, 2, 12, 12, 128)    65664
#
#  activation_43 (Activation)  (None, 2, 12, 12, 128)    0
#
#  batch_normalization_57 (Ba  (None, 2, 12, 12, 128)    512
#  tchNormalization)
#
#  max_pooling3d_31 (MaxPooli  (None, 1, 6, 6, 128)      0
#  ng3D)
#
#  flatten_7 (Flatten)         (None, 4608)              0
#
#  dense_21 (Dense)            (None, 128)               589952
#
#  batch_normalization_58 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dropout_22 (Dropout)        (None, 128)               0
#
#  dense_22 (Dense)            (None, 128)               16512
#
#  batch_normalization_59 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dropout_23 (Dropout)        (None, 128)               0
#
#  dense_23 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 696645 (2.66 MB)
# Trainable params: 695653 (2.65 MB)
# Non-trainable params: 992 (3.88 KB)
# _________________________________________________________________

# %%
print("Total Params:", conv_3d13_model.count_params())
history_model13=conv_3d13.train_model(conv_3d13_model,augment_data=True)
# Out:
# Total Params: 696645
# Epoch 1/25
# 2024-03-03 15:24:54.355662: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f2f1e6b6d80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-03-03 15:24:54.355708: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1650, Compute Capability 7.5
# 2024-03-03 15:24:54.379012: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1709459694.501879    8926 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2024-03-03 15:25:07.567855: W external/local_tsl/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 390.62MiB (rounded to 409600000)requested by op gradient_tape/sequential_7/max_pooling3d_28/MaxPool3D/MaxPool3DGrad
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2024-03-03 15:25:07.567913: I external/local_tsl/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2024-03-03 15:25:07.567922: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 370, Chunks in use: 368. 92.5KiB allocated for chunks. 92.0KiB in use in bin. 35.9KiB client-requested in use in bin.
# 2024-03-03 15:25:07.567926: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 113, Chunks in use: 112. 57.0KiB allocated for chunks. 56.2KiB in use in bin. 56.0KiB client-requested in use in bin.
# 2024-03-03 15:25:07.567929: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 92, Chunks in use: 90. 96.2KiB allocated for chunks. 94.2KiB in use in bin. 91.5KiB client-requested in use in bin.
# 2024-03-03 15:25:07.567932: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 4, Chunks in use: 4. 10.0KiB allocated for chunks. 10.0KiB in use in bin. 10.0KiB client-requested in use in bin.
# 2024-03-03 15:25:07.567935: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 21, Chunks in use: 21. 112.5KiB allocated for chunks. 112.5KiB in use in bin. 105.7KiB client-requested in use in bin.
# 2024-03-03 15:25:07.567940: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 2, Chunks in use: 2. 17.5KiB allocated for chunks. 17.5KiB in use in bin. 10.1KiB client-requested in use in bin.
# 2024-03-03 15:25:07.567943: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 11, Chunks in use: 11. 232.2KiB allocated for chunks. 232.2KiB in use in bin. 220.0KiB client-requested in use in bin.
# 2024-03-03 15:25:07.567946: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 7, Chunks in use: 6. 344.5KiB allocated for chunks. 307.0KiB in use in bin. 297.0KiB client-requested in use in bin.
# 2024-03-03 15:25:07.567949: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 19, Chunks in use: 19. 1.56MiB allocated for chunks. 1.56MiB in use in bin. 1.37MiB client-requested in use in bin.
# 2024-03-03 15:25:07.567952: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 6, Chunks in use: 6. 1.27MiB allocated for chunks. 1.27MiB in use in bin. 1.27MiB client-requested in use in bin.
# 2024-03-03 15:25:07.567955: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 25, Chunks in use: 25. 7.53MiB allocated for chunks. 7.53MiB in use in bin. 7.03MiB client-requested in use in bin.
# 2024-03-03 15:25:07.567958: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 6, Chunks in use: 6. 5.06MiB allocated for chunks. 5.06MiB in use in bin. 5.06MiB client-requested in use in bin.
# 2024-03-03 15:25:07.567961: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 8, Chunks in use: 6. 12.02MiB allocated for chunks. 9.27MiB in use in bin. 8.44MiB client-requested in use in bin.
# 2024-03-03 15:25:07.567964: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 5, Chunks in use: 4. 13.38MiB allocated for chunks. 9.50MiB in use in bin. 8.44MiB client-requested in use in bin.
# 2024-03-03 15:25:07.567967: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 8, Chunks in use: 8. 47.25MiB allocated for chunks. 47.25MiB in use in bin. 45.12MiB client-requested in use in bin.
# 2024-03-03 15:25:07.567969: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 3, Chunks in use: 3. 36.50MiB allocated for chunks. 36.50MiB in use in bin. 31.12MiB client-requested in use in bin.
# 2024-03-03 15:25:07.567974: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 1, Chunks in use: 1. 24.16MiB allocated for chunks. 24.16MiB in use in bin. 12.50MiB client-requested in use in bin.
# 2024-03-03 15:25:07.567977: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 1, Chunks in use: 1. 48.83MiB allocated for chunks. 48.83MiB in use in bin. 48.83MiB client-requested in use in bin.
# 2024-03-03 15:25:07.567980: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 3, Chunks in use: 2. 244.14MiB allocated for chunks. 146.48MiB in use in bin. 122.07MiB client-requested in use in bin.
# 2024-03-03 15:25:07.567983: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 1, Chunks in use: 0. 244.14MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-03 15:25:07.567986: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 4, Chunks in use: 3. 1.52GiB allocated for chunks. 1.14GiB in use in bin. 1.14GiB client-requested in use in bin.
# 2024-03-03 15:25:07.567989: I external/local_tsl/tsl/framework/bfc_allocator.cc:1062] Bin for 390.62MiB was 256.00MiB, Chunk State:
# 2024-03-03 15:25:07.567995: I external/local_tsl/tsl/framework/bfc_allocator.cc:1068]   Size: 389.81MiB | Requested Size: 16.0KiB | in_use: 0 | bin_num: 20, prev:   Size: 390.62MiB | Requested Size: 390.62MiB | in_use: 1 | bin_num: -1
# 2024-03-03 15:25:07.567997: I external/local_tsl/tsl/framework/bfc_allocator.cc:1075] Next region of size 2357670656
# 2024-03-03 15:25:07.568000: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00000 of size 256 next 1
# 2024-03-03 15:25:07.568002: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00100 of size 1280 next 2
# 2024-03-03 15:25:07.568004: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c
I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1835008 totalling 1.75MiB
# 2024-03-03 15:25:07.571025: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 2359296 totalling 6.75MiB
# 2024-03-03 15:25:07.571338: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 2883584 totalling 2.75MiB
# 2024-03-03 15:25:07.571344: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 4587520 totalling 4.38MiB
# 2024-03-03 15:25:07.571347: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 7 Chunks of size 6422528 totalling 42.88MiB
# 2024-03-03 15:25:07.571349: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 12058624 totalling 11.50MiB
# 2024-03-03 15:25:07.571352: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 13107200 totalling 25.00MiB
# 2024-03-03 15:25:07.571354: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 25329664 totalling 24.16MiB
# 2024-03-03 15:25:07.571357: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 51200000 totalling 48.83MiB
# 2024-03-03 15:25:07.571359: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 76800000 totalling 146.48MiB
# 2024-03-03 15:25:07.571361: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 409600000 totalling 1.14GiB
# 2024-03-03 15:25:07.571364: I external/local_tsl/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 1.47GiB
# 2024-03-03 15:25:07.571367: I external/local_tsl/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 2357670656 memory_limit_: 2357670708 available bytes: 52 curr_region_allocation_bytes_: 4715341824
# 2024-03-03 15:25:07.571373: I external/local_tsl/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                      2357670708
# InUse:                      1583534848
# MaxInUse:                   2106066432
# NumAllocs:                        1600
# MaxAllocSize:               1310720000
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2024-03-03 15:25:07.571387: W external/local_tsl/tsl/framework/bfc_allocator.cc:497] *******************************__________***___************************************_________________
# 2024-03-03 15:25:07.571404: W tensorflow/core/framework/op_kernel.cc:1839] OP_REQUIRES failed at cudnn_pooling_gpu.cc:211 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[40,16,16,100,100] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc

# %%
plot(history_model13)

# %% [markdown]
# ## Model 14 with Augmentation
# ### Reducing network parameters again - Similar to model 7

# %%
class ModelConv3D14(ModelBuilderMoreAugmentation):

    def define_model(self,dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (3, 3, 3), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam(learning_rate=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d14=ModelConv3D14()
conv_3d14.initialize_path(project_folder)
conv_3d14.initialize_image_properties(image_height=120,image_width=120)
conv_3d14.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=25)
conv_3d14_model=conv_3d14.define_model(dense_neurons=64,dropout=0.25)
conv_3d14_model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_48 (Conv3D)          (None, 16, 120, 120, 16   1312
#                              )
#
#  activation_48 (Activation)  (None, 16, 120, 120, 16   0
#                              )
#
#  batch_normalization_66 (Ba  (None, 16, 120, 120, 16   64
#  tchNormalization)           )
#
#  max_pooling3d_36 (MaxPooli  (None, 8, 60, 60, 16)     0
#  ng3D)
#
#  conv3d_49 (Conv3D)          (None, 8, 60, 60, 32)     13856
#
#  activation_49 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_67 (Ba  (None, 8, 60, 60, 32)     128
#  tchNormalization)
#
#  max_pooling3d_37 (MaxPooli  (None, 4, 30, 30, 32)     0
#  ng3D)
#
#  conv3d_50 (Conv3D)          (None, 4, 30, 30, 64)     16448
#
#  activation_50 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_68 (Ba  (None, 4, 30, 30, 64)     256
#  tchNormalization)
#
#  max_pooling3d_38 (MaxPooli  (None, 2, 15, 15, 64)     0
#  ng3D)
#
#  conv3d_51 (Conv3D)          (None, 2, 15, 15, 128)    65664
#
#  activation_51 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_69 (Ba  (None, 2, 15, 15, 128)    512
#  tchNormalization)
#
#  max_pooling3d_39 (MaxPooli  (None, 1, 7, 7, 128)      0
#  ng3D)
#
#  flatten_9 (Flatten)         (None, 6272)              0
#
#  dense_27 (Dense)            (None, 64)                401472
#
#  batch_normalization_70 (Ba  (None, 64)                256
#  tchNormalization)
#
#  dropout_26 (Dropout)        (None, 64)                0
#
#  dense_28 (Dense)            (None, 64)                4160
#
#  batch_normalization_71 (Ba  (None, 64)                256
#  tchNormalization)
#
#  dropout_27 (Dropout)        (None, 64)                0
#
#  dense_29 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 504709 (1.93 MB)
# Trainable params: 503973 (1.92 MB)
# Non-trainable params: 736 (2.88 KB)
# _________________________________________________________________

# %%
print("Total Params:", conv_3d14_model.count_params())
history_model14=conv_3d14.train_model(conv_3d14_model,augment_data=True)
# Out:
# Total Params: 504709
# Epoch 1/25
# 2024-03-03 15:25:56.371910: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 664.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-03 15:25:56.393844: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 664.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-03 15:25:56.645338: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 268.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-03 15:25:56.689199: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 268.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-03 15:26:07.000251: W external/local_tsl/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 140.62MiB (rounded to 147456000)requested by op gradient_tape/sequential_9/max_pooling3d_37/MaxPool3D/MaxPool3DGrad
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2024-03-03 15:26:07.000459: I external/local_tsl/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2024-03-03 15:26:07.000548: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 401, Chunks in use: 398. 100.2KiB allocated for chunks. 99.5KiB in use in bin. 40.0KiB client-requested in use in bin.
# 2024-03-03 15:26:07.000579: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 102, Chunks in use: 98. 51.5KiB allocated for chunks. 49.0KiB in use in bin. 49.0KiB client-requested in use in bin.
# 2024-03-03 15:26:07.000596: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 86, Chunks in use: 83. 91.2KiB allocated for chunks. 88.0KiB in use in bin. 85.3KiB client-requested in use in bin.
# 2024-03-03 15:26:07.000612: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 7, Chunks in use: 3. 17.0KiB allocated for chunks. 7.5KiB in use in bin. 7.5KiB client-requested in use in bin.
# 2024-03-03 15:26:07.000630: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 22, Chunks in use: 20. 119.8KiB allocated for chunks. 107.8KiB in use in bin. 100.7KiB client-requested in use in bin.
# 2024-03-03 15:26:07.000647: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 4, Chunks in use: 3. 37.8KiB allocated for chunks. 27.0KiB in use in bin. 15.1KiB client-requested in use in bin.
# 2024-03-03 15:26:07.000663: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 16, Chunks in use: 12. 322.5KiB allocated for chunks. 237.5KiB in use in bin. 225.0KiB client-requested in use in bin.
# 2024-03-03 15:26:07.000680: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 8, Chunks in use: 7. 415.0KiB allocated for chunks. 361.0KiB in use in bin. 351.0KiB client-requested in use in bin.
# 2024-03-03 15:26:07.000696: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 24, Chunks in use: 20. 1.89MiB allocated for chunks. 1.58MiB in use in bin. 1.38MiB client-requested in use in bin.
# 2024-03-03 15:26:07.000711: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 6, Chunks in use: 5. 1.18MiB allocated for chunks. 1.05MiB in use in bin. 1.05MiB client-requested in use in bin.
# 2024-03-03 15:26:07.000726: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 27, Chunks in use: 25. 7.89MiB allocated for chunks. 7.34MiB in use in bin. 6.86MiB client-requested in use in bin.
# 2024-03-03 15:26:07.000742: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 6, Chunks in use: 5. 5.06MiB allocated for chunks. 4.22MiB in use in bin. 4.22MiB client-requested in use in bin.
# 2024-03-03 15:26:07.000759: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 10, Chunks in use: 8. 15.03MiB allocated for chunks. 12.33MiB in use in bin. 11.34MiB client-requested in use in bin.
# 2024-03-03 15:26:07.000775: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 5, Chunks in use: 3. 12.62MiB allocated for chunks. 7.25MiB in use in bin. 6.19MiB client-requested in use in bin.
# 2024-03-03 15:26:07.000791: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 8, Chunks in use: 7. 47.25MiB allocated for chunks. 41.12MiB in use in bin. 39.00MiB client-requested in use in bin.
# 2024-03-03 15:26:07.000807: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 3, Chunks in use: 3. 36.50MiB allocated for chunks. 36.50MiB in use in bin. 31.12MiB client-requested in use in bin.
# 2024-03-03 15:26:07.000824: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 4, Chunks in use: 4. 76.89MiB allocated for chunks. 76.89MiB in use in bin. 65.23MiB client-requested in use in bin.
# 2024-03-03 15:26:07.000840: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-03 15
I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 337920 totalling 330.0KiB
# 2024-03-03 15:26:07.009498: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 360448 totalling 352.0KiB
# 2024-03-03 15:26:07.009500: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 393216 totalling 384.0KiB
# 2024-03-03 15:26:07.009503: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 4 Chunks of size 442368 totalling 1.69MiB
# 2024-03-03 15:26:07.009505: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 5 Chunks of size 884736 totalling 4.22MiB
# 2024-03-03 15:26:07.009507: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1245184 totalling 1.19MiB
# 2024-03-03 15:26:07.009510: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1327104 totalling 1.27MiB
# 2024-03-03 15:26:07.009873: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 1605632 totalling 3.06MiB
# 2024-03-03 15:26:07.009883: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 1769472 totalling 5.06MiB
# 2024-03-03 15:26:07.009886: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1835008 totalling 1.75MiB
# 2024-03-03 15:26:07.009888: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 2359296 totalling 4.50MiB
# 2024-03-03 15:26:07.009890: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 2883584 totalling 2.75MiB
# 2024-03-03 15:26:07.009893: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 4587520 totalling 4.38MiB
# 2024-03-03 15:26:07.009895: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 6 Chunks of size 6422528 totalling 36.75MiB
# 2024-03-03 15:26:07.009898: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 12058624 totalling 11.50MiB
# 2024-03-03 15:26:07.009900: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 13107200 totalling 25.00MiB
# 2024-03-03 15:26:07.009903: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 18432000 totalling 52.73MiB
# 2024-03-03 15:26:07.009905: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 25329664 totalling 24.16MiB
# 2024-03-03 15:26:07.009908: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 73728000 totalling 70.31MiB
# 2024-03-03 15:26:07.009910: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 110592000 totalling 210.94MiB
# 2024-03-03 15:26:07.009913: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 4 Chunks of size 147456000 totalling 562.50MiB
# 2024-03-03 15:26:07.009915: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 589824000 totalling 1.10GiB
# 2024-03-03 15:26:07.009917: I external/local_tsl/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 2.11GiB
# 2024-03-03 15:26:07.009921: I external/local_tsl/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 2357670656 memory_limit_: 2357670708 available bytes: 52 curr_region_allocation_bytes_: 4715341824
# 2024-03-03 15:26:07.009926: I external/local_tsl/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                      2357670708
# InUse:                      2262812928
# MaxInUse:                   2262812928
# NumAllocs:                        2149
# MaxAllocSize:               1310720000
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2024-03-03 15:26:07.009944: W external/local_tsl/tsl/framework/bfc_allocator.cc:497] **********x**************************************************************************************___
# 2024-03-03 15:26:07.009963: W tensorflow/core/framework/op_kernel.cc:1839] OP_REQUIRES failed at cudnn_pooling_gpu.cc:232 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[40,32,8,60,60] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc

# %%
plot(history_model14)

# %% [markdown]
# ## Model 15 with Augmentation
# ### CNN LSTM with GRU - Similar to Model 8

# %%
class RNNCNN2(ModelBuilderMoreAugmentation):

    def define_model(self,lstm_cells=64,dense_neurons=64,dropout=0.25):

        model = Sequential()

        model.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu'),
                                  input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))

        model.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))

        model.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))

        model.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))


        model.add(TimeDistributed(Flatten()))


        model.add(GRU(lstm_cells))
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(Dropout(dropout))

        model.add(Dense(self.num_classes, activation='softmax'))
        optimiser = optimizers.Adam(learning_rate=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
rnn_cnn2=RNNCNN2()
rnn_cnn2.initialize_path(project_folder)
rnn_cnn2.initialize_image_properties(image_height=120,image_width=120)
rnn_cnn2.initialize_hyperparams(frames_to_sample=18,batch_size=20,num_epochs=20)
rnn_cnn2_model=rnn_cnn2.define_model(lstm_cells=128,dense_neurons=128,dropout=0.25)
rnn_cnn2_model.summary()
# Out:
# cc:1095] InUse at 609a1bb00 of size 256 next 505
# 2024-03-03 15:26:57.918049: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a1bc00 of size 256 next 507
# 2024-03-03 15:26:57.918057: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a1bd00 of size 256 next 508
# 2024-03-03 15:26:57.918065: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a1be00 of size 256 next 511
# 2024-03-03 15:26:57.918073: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a1bf00 of size 256 next 509
# 2024-03-03 15:26:57.918081: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a1c000 of size 256 next 510
# 2024-03-03 15:26:57.918089: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a
: RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[720,16,120,120] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc

# %%
print("Total Params:", rnn_cnn2_model.count_params())
history_model15=rnn_cnn2.train_model(rnn_cnn2_model,augment_data=True)
# Out:
# Total Params: 2573925
# Epoch 1/20
# 2024-03-03 15:26:47.022858: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-03 15:26:47.148997: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.67GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-03 15:26:47.410127: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.44GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-03 15:26:57.911831: W external/local_tsl/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 632.81MiB (rounded to 663552000)requested by op gradient_tape/sequential_10/time_distributed_1/batch_normalization_72/FusedBatchNormGradV3-1-TransposeNHWCToNCHW-LayoutOptimizer
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2024-03-03 15:26:57.912012: I external/local_tsl/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2024-03-03 15:26:57.912059: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 448, Chunks in use: 447. 112.0KiB allocated for chunks. 111.8KiB in use in bin. 44.6KiB client-requested in use in bin.
# 2024-03-03 15:26:57.912078: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 113, Chunks in use: 113. 56.8KiB allocated for chunks. 56.8KiB in use in bin. 56.3KiB client-requested in use in bin.
# 2024-03-03 15:26:57.912096: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 84, Chunks in use: 84. 89.0KiB allocated for chunks. 89.0KiB in use in bin. 86.0KiB client-requested in use in bin.
# 2024-03-03 15:26:57.912112: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 10, Chunks in use: 10. 25.5KiB allocated for chunks. 25.5KiB in use in bin. 23.1KiB client-requested in use in bin.
# 2024-03-03 15:26:57.912129: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 23, Chunks in use: 22. 123.2KiB allocated for chunks. 117.5KiB in use in bin. 106.7KiB client-requested in use in bin.
# 2024-03-03 15:26:57.912145: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 3, Chunks in use: 3. 27.0KiB allocated for chunks. 27.0KiB in use in bin. 15.1KiB client-requested in use in bin.
# 2024-03-03 15:26:57.912162: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 16, Chunks in use: 15. 324.5KiB allocated for chunks. 308.5KiB in use in bin. 279.0KiB client-requested in use in bin.
# 2024-03-03 15:26:57.912178: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 8, Chunks in use: 7. 397.0KiB allocated for chunks. 361.0KiB in use in bin. 351.0KiB client-requested in use in bin.
# 2024-03-03 15:26:57.912194: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 25, Chunks in use: 25. 1.96MiB allocated for chunks. 1.96MiB in use in bin. 1.71MiB client-requested in use in bin.
# 2024-03-03 15:26:57.912209: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 8, Chunks in use: 8. 1.57MiB allocated for chunks. 1.57MiB in use in bin. 1.50MiB client-requested in use in bin.
# 2024-03-03 15:26:57.912361: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 29, Chunks in use: 29. 8.46MiB allocated for chunks. 8.46MiB in use in bin. 7.89MiB client-requested in use in bin.
# 2024-03-03 15:26:57.912392: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 6, Chunks in use: 5. 5.05MiB allocated for chunks. 4.22MiB in use in bin. 4.22MiB client-requested in use in bin.
# 2024-03-03 15:26:57.912414: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 9, Chunks in use: 8. 14.02MiB allocated for chunks. 12.33MiB in use in bin. 11.34MiB client-requested in use in bin.
# 2024-03-03 15:26:57.912433: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 5, Chunks in use: 3. 12.62MiB allocated for chunks. 7.25MiB in use in bin. 6.19MiB client-requested in use in bin.
# 2024-03-03 15:26:57.912451: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 8, Chunks in use: 7. 47.25MiB allocated for chunks. 41.12MiB in use in bin. 39.00MiB client-requested in use in bin.
# 2024-03-03 15:26:57.912468: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 6, Chunks in use: 6. 64.06MiB allocated for chunks. 64.06MiB in use in bin. 58.69MiB client-requested in use in bin.
# 2024-03-03 15:26:57.912484: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 1, Chunks in use: 1. 24.16MiB allocated for chunks. 24.16MiB in use in bin. 12.50MiB client-requested in use in bin.
# 2024-03-03 15:26:57.912500: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-03 15:26:57.912522: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 2, Chunks in use: 1. 237.30MiB allocated for chunks. 118.65MiB in use in bin. 118.65MiB client-requested in use in bin.
# 2024-03-03 15:26:57.912535: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-03 15:26:57.912551: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 3, Chunks in use: 2. 1.79GiB allocated for chunks. 1.24GiB in use in bin. 1.24GiB client-requested in use in bin.
# 2024-03-03 15:26:57.912567: I external/local_tsl/tsl/framework/bfc_allocator.cc:1062] Bin for 632.81MiB was 256.00MiB, Chunk State:
# 2024-03-03 15:26:57.912591: I external/local_tsl/tsl/framework/bfc_allocator.cc:1068]   Size: 565.24MiB | Requested Size: 128B | in_use: 0 | bin_num: 20, prev:   Size: 632.81MiB | Requested Size: 632.81MiB | in_use: 1 | bin_num: -1
# 2024-03-03 15:26:57.912603: I external/local_tsl/tsl/framework/bfc_allocator.cc:1075] Next region of size 2357670656
# 2024-03-03 15:26:57.912617: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00000 of size 256 next 1
# 2024-03-03 15:26:57.912680: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00100 of size 1280 next 2
# 2024-03-03 15:26:57.912698: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00600 of size 256 next 3
# 2024-03-03 15:26:57.912712: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00700 of size 256 next 4
# 2024-03-03 15:26:57.912724: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00800 of size 256 next 6
# 2024-03-03 15:26:57.912735: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00900 of size 256 next 7
# 2024-03-03 15:26:57.912744: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00a00 of size 256 next 5
# 2024-03-03 15:26:57.912754: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00b00 of size 256 next 8
# 2024-03-03 15:26:57.912765: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00c00 of size 256 next 11
# 2024-03-03 15:26:57.912775: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00d00 of size 256 next 12
# 2024-03-03 15:26:57.912786: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00e00 of size 256 next 13
# 2024-03-03 15:26:57.912796: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00f00 of size 256 next 14
# 2024-03-03 15:26:57.912805: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01000 of size 256 next 15
# 2024-03-03 15:26:57.912815: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01100 of size 256 next 18
# 2024-03-03 15:26:57.912825: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01200 of size 256 next 16
# 2024-03-03 15:26:57.912836: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01300 of size 256 next 17
# 2024-03-03 15:26:57.912846: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01400 of size 256 next 21
# 2024-03-03 15:26:57.912856: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01500 of size 256 next 22
# 2024-03-03 15:26:57.912867: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01600 of size 256 next 23
# 2024-03-03 15:26:57.912877: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01700 of size 256 next 24
# 2024-03-03 15:26:57.912888: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01800 of size 256 next 27
# 2024-03-03 15:26:57.912897: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01900 of size 256 next 25
# 2024-03-03 15:26:57.912909: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01a00 of size 256 next 26
# 2024-03-03 15:26:57.912919: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01b00 of size 256 next 30
# 2024-03-03 15:26:57.912930: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01c00 of size 256 next 31
# 2024-03-03 15:26:57.912941: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01d00 of size 256 next 32
# 2024-03-03 15:26:57.912951: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01e00 of size 256 next 33
# 2024-03-03 15:26:57.912962: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01f00 of size 512 next 36
# 2024-03-03 15:26:57.912972: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c02100 of size 512 next 34
# 2024-03-03 15:26:57.912983: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c02300 of size 512 next 35
# 2024-03-03 15:26:57.912993: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c02500 of size 512 next 39
# 2024-03-03 15:26:57.913003: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c02700 of size 512 next 40
# 2024-03-03 15:26:57.913013: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c02900 of size 256 next 41
# 2024-03-03 15:26:57.913024: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c02a00 of size 256 next 42
# 2024-03-03 15:26:57.913035: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c02b00 of size 1024 next 45
# 2024-03-03 15:26:57.913047: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c
I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 607257200 of size 2883584 next 168
# 2024-03-03 15:26:57.917550: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 607517200 of size 262144 next 218
# 2024-03-03 15:26:57.917561: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 607557200 of size 262144 next 246
# 2024-03-03 15:26:57.917571: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 607597200 of size 262144 next 259
# 2024-03-03 15:26:57.917582: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 6075d7200 of size 262144 next 260
# 2024-03-03 15:26:57.917590: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 607617200 of size 110592 next 349
# 2024-03-03 15:26:57.917599: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 607632200 of size 110592 next 283
# 2024-03-03 15:26:57.917607: I external/local_tsl/tsl/f
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /tmp/ipykernel_8850/2916011372.py in <module>
#       1 print("Total Params:", rnn_cnn2_model.count_params())
# ----> 2 history_model15=rnn_cnn2.train_model(rnn_cnn2_model,augment_data=True)
#
# /tmp/ipykernel_8850/1912833249.py in train_model(self, model, augment_data)
#     124             validation_steps = (self.num_val_sequences//self.batch_size) + 1
#     125
# --> 126         history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=self.num_epochs, verbose=1,
#     127                             callbacks=callbacks_list, validation_data=val_generator,
#     128                             validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
#
# ~/.local/lib/python3.10/site-packages/keras/src/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2911             stacklevel=2,
#    2912         )
# -> 2913         return self.fit(
#    2914             generator,
#    2915             steps_per_epoch=steps_per_epoch,
#
# ~/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node gradient_tape/sequential_10/time_distributed_1/batch_normalization_72/FusedBatchNormGradV3-1-TransposeNHWCToNCHW-LayoutOptimizer defined at (most recent call last):
# <stack traces unavailable>
# OOM when allocating tensor with shape[720,16,120,120] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node gradient_tape/sequential_10/time_distributed_1/batch_normalization_72/FusedBatchNormGradV3-1-TransposeNHWCToNCHW-LayoutOptimizer}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_27952]
# ramework/bfc_allocator.cc:1095] InUse at 60764d200 of size 221184 next 282
# 2024-03-03 15:26:57.917615: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 607683200 of size 262144 next 320
# 2024-03-03 15:26:57.917623: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 6076c3200 of size 262144 next 319
# 2024-03-03 15:26:57.917632: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 607703200 of size 360448 next 293
# 2024-03-03 15:26:57.917641: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 60775b200 of size 442368 next 292
# 2024-03-03 15:26:57.917650: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 6077c7200 of size 442368 next 362
# 2024-03-03 15:26:57.917658: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 607833200 of size 442368 next 299
# 2024-03-03 15:26:57.917667: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 60789f200 of size 884736 next 298
# 2024-03-03 15:26:57.917712: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 607977200 of size 1835008 next 213
# 2024-03-03 15:26:57.917725: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 607b37200 of size 6422528 next 212
# 2024-03-03 15:26:57.917734: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 608157200 of size 6422528 next 253
# 2024-03-03 15:26:57.917743: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 608777200 of size 6422528 next 382
# 2024-03-03 15:26:57.917751: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 608d97200 of size 6422528 next 315
# 2024-03-03 15:26:57.917759: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 6093b7200 of size 6422528 next 314
# 2024-03-03 15:26:57.917768: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 6099d7200 of size 262144 next 388
# 2024-03-03 15:26:57.917777: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a17200 of size 256 next 514
# 2024-03-03 15:26:57.917786: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a17300 of size 256 next 515
# 2024-03-03 15:26:57.917795: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a17400 of size 256 next 517
# 2024-03-03 15:26:57.917803: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a17500 of size 256 next 518
# 2024-03-03 15:26:57.917811: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a17600 of size 256 next 519
# 2024-03-03 15:26:57.917819: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a17700 of size 512 next 522
# 2024-03-03 15:26:57.917828: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a17900 of size 512 next 520
# 2024-03-03 15:26:57.917836: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a17b00 of size 512 next 521
# 2024-03-03 15:26:57.917844: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a17d00 of size 512 next 523
# 2024-03-03 15:26:57.917851: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a17f00 of size 512 next 525
# 2024-03-03 15:26:57.917860: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a18100 of size 512 next 526
# 2024-03-03 15:26:57.917868: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a18300 of size 512 next 527
# 2024-03-03 15:26:57.917876: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a18500 of size 512 next 530
# 2024-03-03 15:26:57.917884: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a18700 of size 512 next 531
# 2024-03-03 15:26:57.917893: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a18900 of size 512 next 532
# 2024-03-03 15:26:57.917902: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a18b00 of size 1024 next 533
# 2024-03-03 15:26:57.917910: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a18f00 of size 1024 next 534
# 2024-03-03 15:26:57.917918: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a19300 of size 1792 next 483
# 2024-03-03 15:26:57.917927: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a19a00 of size 5120 next 482
# 2024-03-03 15:26:57.917935: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a1ae00 of size 256 next 489
# 2024-03-03 15:26:57.917943: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a1af00 of size 256 next 490
# 2024-03-03 15:26:57.917951: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a1b000 of size 256 next 491
# 2024-03-03 15:26:57.917960: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a1b100 of size 256 next 492
# 2024-03-03 15:26:57.917968: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a1b200 of size 256 next 494
# 2024-03-03 15:26:57.917976: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a1b300 of size 256 next 495
# 2024-03-03 15:26:57.917984: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a1b400 of size 256 next 498
# 2024-03-03 15:26:57.917992: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a1b500 of size 256 next 496
# 2024-03-03 15:26:57.918000: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a1b600 of size 256 next 497
# 2024-03-03 15:26:57.918008: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a1b700 of size 256 next 501
# 2024-03-03 15:26:57.918016: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a1b800 of size 256 next 502
# 2024-03-03 15:26:57.918025: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a1b900 of size 256 next 503
# 2024-03-03 15:26:57.918033: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 609a1ba00 of size 256 next 504
# 2024-03-03 15:26:57.918041: I external/local_tsl/tsl/framework/bfc_allocator.

# %%
plot(history_model15)

# %% [markdown]
# ### We see that overfitting is considerably high when we do more augmentation. However there is not much improvement on accuracy

# %% [markdown]
# ## Model 16 - Let us bring in Transfer Learning !! :)
# ### (Optional)

# %%
# importing the MobileNet model due to it's lightweight architecture and high speed performance as compared
# to other heavy-duty models like VGG16, Alexnet, InceptionV3 etc. Also, we are now also running on low disk space
# in the nimblebox.ai platform.

from keras.applications import mobilenet

# %%
mobilenet_transfer = mobilenet.MobileNet(weights='imagenet', include_top=False)

class RNNCNN_TL(ModelBuilderMoreAugmentation):

    def define_model(self,lstm_cells=64,dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(TimeDistributed(mobilenet_transfer,input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))


        for layer in model.layers:
            layer.trainable = False


        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        model.add(TimeDistributed(Flatten()))

        model.add(LSTM(lstm_cells))
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(Dropout(dropout))

        model.add(Dense(self.num_classes, activation='softmax'))


        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 [==============================] - 3s 0us/step

# %%
rnn_cnn_tl=RNNCNN_TL()
rnn_cnn_tl.initialize_path(project_folder)
rnn_cnn_tl.initialize_image_properties(image_height=120,image_width=120)
rnn_cnn_tl.initialize_hyperparams(frames_to_sample=16,batch_size=5,num_epochs=20)
rnn_cnn_tl_model=rnn_cnn_tl.define_model(lstm_cells=128,dense_neurons=128,dropout=0.25)
rnn_cnn_tl_model.summary()

# %%
print("Total Params:", rnn_cnn_tl_model.count_params())
history_model16=rnn_cnn_tl.train_model(rnn_cnn_tl_model,augment_data=True)

# %%
plot(history_model16)

# %% [markdown]
# ### We are not training the mobilenet weights and we see validation accuracy is very poor. Let's train them as well and observe if there is performance improvement

# %% [markdown]
# ## Model 17 - Transfer Learning with GRU and training all weights
# ### (Optional)

# %%
from keras.applications import mobilenet

mobilenet_transfer = mobilenet.MobileNet(weights='imagenet', include_top=False)

class RNNCNN_TL2(ModelBuilderMoreAugmentation):

    def define_model(self,gru_cells=64,dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(TimeDistributed(mobilenet_transfer,input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))


        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        model.add(TimeDistributed(Flatten()))

        model.add(GRU(gru_cells))
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(Dropout(dropout))

        model.add(Dense(self.num_classes, activation='softmax'))


        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
rnn_cnn_tl2=RNNCNN_TL2()
rnn_cnn_tl2.initialize_path(project_folder)
rnn_cnn_tl2.initialize_image_properties(image_height=120,image_width=120)
rnn_cnn_tl2.initialize_hyperparams(frames_to_sample=16,batch_size=5,num_epochs=20)
rnn_cnn_tl2_model=rnn_cnn_tl2.define_model(gru_cells=128,dense_neurons=128,dropout=0.25)
rnn_cnn_tl2_model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_13 (TimeD  (None, 16, 3, 3, 1024)    3228864
#  istributed)
#
#  time_distributed_14 (TimeD  (None, 16, 3, 3, 1024)    4096
#  istributed)
#
#  time_distributed_15 (TimeD  (None, 16, 1, 1, 1024)    0
#  istributed)
#
#  time_distributed_16 (TimeD  (None, 16, 1024)          0
#  istributed)
#
#  gru_1 (GRU)                 (None, 128)               443136
#
#  dropout_30 (Dropout)        (None, 128)               0
#
#  dense_32 (Dense)            (None, 128)               16512
#
#  dropout_31 (Dropout)        (None, 128)               0
#
#  dense_33 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 3693253 (14.09 MB)
# Trainable params: 3669317 (14.00 MB)
# Non-trainable params: 23936 (93.50 KB)
# _________________________________________________________________

# %%
print("Total Params:", rnn_cnn_tl2_model.count_params())
history_model17=rnn_cnn_tl2.train_model(rnn_cnn_tl2_model,augment_data=True)
# Out:
# Total Params: 3693253
# Epoch 1/20
# 2024-03-03 15:29:40.092038: W external/local_tsl/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 20.00MiB (rounded to 20971520)requested by op sequential_11/time_distributed_13/mobilenet_1.00_224/conv_pad_12/Pad
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2024-03-03 15:29:40.092154: I external/local_tsl/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2024-03-03 15:29:40.092179: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 526, Chunks in use: 526. 131.5KiB allocated for chunks. 131.5KiB in use in bin. 52.5KiB client-requested in use in bin.
# 2024-03-03 15:29:40.092188: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 155, Chunks in use: 155. 78.2KiB allocated for chunks. 78.2KiB in use in bin. 77.5KiB client-requested in use in bin.
# 2024-03-03 15:29:40.092198: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 125, Chunks in use: 125. 131.8KiB allocated for chunks. 131.8KiB in use in bin. 127.5KiB client-requested in use in bin.
# 2024-03-03 15:29:40.092206: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 141, Chunks in use: 139. 298.8KiB allocated for chunks. 294.8KiB in use in bin. 287.2KiB client-requested in use in bin.
# 2024-03-03 15:29:40.092214: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 63, Chunks in use: 62. 301.5KiB allocated for chunks. 297.5KiB in use in bin. 268.1KiB client-requested in use in bin.
# 2024-03-03 15:29:40.092246: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 12, Chunks in use: 12. 111.8KiB allocated for chunks. 111.8KiB in use in bin. 93.1KiB client-requested in use in bin.
# 2024-03-03 15:29:40.092255: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 33, Chunks in use: 33. 637.5KiB allocated for chunks. 637.5KiB in use in bin. 603.0KiB client-requested in use in bin.
# 2024-03-03 15:29:40.092263: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 11, Chunks in use: 11. 515.5KiB allocated for chunks. 515.5KiB in use in bin. 483.0KiB client-requested in use in bin.
# 2024-03-03 15:29:40.092272: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 33, Chunks in use: 33. 2.49MiB allocated for chunks. 2.49MiB in use in bin. 2.16MiB client-requested in use in bin.
# 2024-03-03 15:29:40.092279: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 15, Chunks in use: 14. 2.81MiB allocated for chunks. 2.62MiB in use in bin. 2.44MiB client-requested in use in bin.
# 2024-03-03 15:29:40.092287: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 32, Chunks in use: 32. 9.40MiB allocated for chunks. 9.40MiB in use in bin. 8.64MiB client-requested in use in bin.
# 2024-03-03 15:29:40.092294: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 8, Chunks in use: 8. 5.72MiB allocated for chunks. 5.72MiB in use in bin. 5.72MiB client-requested in use in bin.
# 2024-03-03 15:29:40.092303: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 25, Chunks in use: 24. 30.52MiB allocated for chunks. 29.52MiB in use in bin. 27.84MiB client-requested in use in bin.
# 2024-03-03 15:29:40.092311: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 9, Chunks in use: 8. 19.75MiB allocated for chunks. 17.25MiB in use in bin. 15.19MiB client-requested in use in bin.
# 2024-03-03 15:29:40.092319: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 13, Chunks in use: 11. 78.22MiB allocated for chunks. 62.91MiB in use in bin. 58.66MiB client-requested in use in bin.
# 2024-03-03 15:29:40.092328: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 28, Chunks in use: 27. 395.55MiB allocated for chunks. 380.23MiB in use in bin. 372.59MiB client-requested in use in bin.
# 2024-03-03 15:29:40.092336: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 7, Chunks in use: 7. 158.21MiB allocated for chunks. 158.21MiB in use in bin. 119.96MiB client-requested in use in bin.
# 2024-03-03 15:29:40.092344: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 9, Chunks in use: 9. 338.83MiB allocated for chunks. 338.83MiB in use in bin. 321.25MiB client-requested in use in bin.
# 2024-03-03 15:29:40.092355: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 11, Chunks in use: 11. 778.20MiB allocated for chunks. 778.20MiB in use in bin. 778.20MiB client-requested in use in bin.
# 2024-03-03 15:29:40.092364: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 3, Chunks in use: 3. 426.60MiB allocated for chunks. 426.60MiB in use in bin. 426.60MiB client-requested in use in bin.
# 2024-03-03 15:29:40.092372: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-03 15:29:40.092393: I external/local_tsl/tsl/framework/bfc_allocator.cc:1062] Bin for 20.00MiB was 16.00MiB, Chunk State:
# 2024-03-03 15:29:40.092400: I external/local_tsl/tsl/framework/bfc_allocator.cc:1075] Next region of size 2357670656
# 2024-03-03 15:29:40.092409: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00000 of size 256 next 1
# 2024-03-03 15:29:40.092414: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00100 of size 1280 next 2
# 2024-03-03 15:29:40.092420: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00600 of size 256 next 3
# 2024-03-03 15:29:40.092425: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00700 of size 256 next 4
# 2024-03-03 15:29:40.092430: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00800 of size 256 next 6
# 2024-03-03 15:29:40.092435: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00900 of size 256 next 7
# 2024-03-03 15:29:40.092440: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00a00 of size 256 next 5
# 2024-03-03 15:29:40.092445: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00b00 of size 256 next 8
# 2024-03-03 15:29:40.092450: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00c00 of size 256 next 11
# 2024-03-03 15:29:40.092455: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00d00 of size 256 next 12
# 2024-03-03 15:29:40.092460: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00e00 of size 256 next 13
# 2024-03-03 15:29:40.092466: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c00f00 of size 256 next 14
# 2024-03-03 15:29:40.092471: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01000 of size 256 next 15
# 2024-03-03 15:29:40.092476: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01100 of size 256 next 18
# 2024-03-03 15:29:40.092481: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01200 of size 256 next 16
# 2024-03-03 15:29:40.092486: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01300 of size 256 next 17
# 2024-03-03 15:29:40.092491: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01400 of size 256 next 21
# 2024-03-03 15:29:40.092496: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01500 of size 256 next 22
# 2024-03-03 15:29:40.092502: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c01600 of size 256 next 23
# 2024-03-03 15:29:40.092507: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 602c
I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 25559040 totalling 24.38MiB
# 2024-03-03 15:29:50.120317: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 27648000 totalling 52.73MiB
# 2024-03-03 15:29:50.120319: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 7 Chunks of size 36864000 totalling 246.09MiB
# 2024-03-03 15:29:50.120322: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 41943040 totalling 40.00MiB
# 2024-03-03 15:29:50.120548: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 55296000 totalling 52.73MiB
# 2024-03-03 15:29:50.120553: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 10 Chunks of size 73728000 totalling 703.12MiB
# 2024-03-03 15:29:50.120557: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 78725120 totalling 75.08MiB
# 2024-03-03 15:29:50.120560: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 147456000 totalling 281.25MiB
# 2024-03-03 15:29:50.120562: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 152412160 totalling 145.35MiB
# 2024-03-03 15:29:50.120565: I external/local_tsl/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 2.16GiB
# 2024-03-03 15:29:50.120569: I external/local_tsl/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 2357670656 memory_limit_: 2357670708 available bytes: 52 curr_region_allocation_bytes_: 4715341824
# 2024-03-03 15:29:50.120575: I external/local_tsl/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                      2357670708
# InUse:                      2321670912
# MaxInUse:                   2338776320
# NumAllocs:                        4076
# MaxAllocSize:               1310720000
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2024-03-03 15:29:50.120603: W external/local_tsl/tsl/framework/bfc_allocator.cc:497] ****************************************************************************************************
# 2024-03-03 15:29:50.120621: W tensorflow/core/framework/op_kernel.cc:1839] OP_REQUIRES failed at pad_op.cc:121 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[81920,8,8] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc

# %%
plot(history_model17)

# %% [markdown]
# ## Awesome results! 98% Training accuracy and 93% validation accuracy :)

# %% [markdown]
# # Consolidated Final Models

# %% [markdown]
# # After doing all the experiments, we finalized Model 8 - CNN+LSTM, which performed well.

# %% [markdown]
# Reason:
#
# - (Training Accuracy : 93%, Validation Accuracy : 85%)
#
# - Number of Parameters(1,657,445)less according to other models performance
#
# - Learning rate gradually decreacing after 16 Epoch
#
# The best weights of CNN-LSTM: model-00020-0.19649-0.93514-0.45695-0.85000.h5 (19 MB). we considered this weight for model testing, Let's have look at the performance below

# %% [markdown]
# # Loading model and Testing

# %%
import time
from keras.models import load_model
model = load_model('model_init_2020-06-2522_00_52.036987/model-00020-0.19649-0.93514-0.45695-0.85000.h5')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_8850/1146057390.py in <module>
#       1 import time
#       2 from keras.models import load_model
# ----> 3 model = load_model('model_init_2020-06-2522_00_52.036987/model-00020-0.19649-0.93514-0.45695-0.85000.h5')
#
# ~/.local/lib/python3.10/site-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     260
#     261     # Legacy case.
# --> 262     return legacy_sm_saving_lib.load_model(
#     263         filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     264     )
#
# ~/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~/.local/lib/python3.10/site-packages/keras/src/saving/legacy/save.py in load_model(filepath, custom_objects, compile, options)
#     232                     if isinstance(filepath_str, str):
#     233                         if not tf.io.gfile.exists(filepath_str):
# --> 234                             raise IOError(
#     235                                 f"No file or directory found at {filepath_str}"
#     236                             )
#
# OSError: No file or directory found at model_init_2020-06-2522_00_52.036987/model-00020-0.19649-0.93514-0.45695-0.85000.h5

# %%
test_generator=RNNCNN1()
test_generator.initialize_path(project_folder)
test_generator.initialize_image_properties(image_height=120,image_width=120)
test_generator.initialize_hyperparams(frames_to_sample=18,batch_size=20,num_epochs=20)

g=test_generator.generator(test_generator.val_path,test_generator.val_doc,augment=False)
batch_data, batch_labels=next(g)

# %%
batch_labels

# %%
print(np.argmax(model.predict(batch_data[:,:,:,:,:]),axis=1))

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'

if not os.path.exists(model_name):
    os.mkdir(model_name)

filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', save_freq=1)

LR = # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                    callbacks=callbacks_list, validation_data=val_generator,
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
